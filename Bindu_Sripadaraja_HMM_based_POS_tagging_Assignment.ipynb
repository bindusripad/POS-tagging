# %% [markdown]
# ## POS tagging using modified Viterbi
#
# <hr />
#
# 1. <B> Problem Statment </B>
#  * Implement atleast 2 methods to tag unknown words using Viterbi algorith,.
#
# 2. <B> DataSet </B>
#  *  Penn Treebank dataset of NLTK (with 'universal' tagset)
#  *  The dataset consisis of 12 POS tags which are of  Verb, Noun, Pronouns, Adjectives, Adverbs, Adpositions, Conjunctions,Determiners, Cardinal Numbers, Particles, Other/ Foreign words, Punctuations
#
# 3. <b>Objectives </b>
#   * First implement the vanilla Viterbi algorithm for assigning POS tags
#   * Then use different methods (atleast 2) to tag unknown words.
#   * Compute the accuracy for these two methods and compare with the vanilla Viterbi accuracy.
#   * List down at least three cases from the sample test file (i.e. unknown word-tag pairs) which were incorrectly tagged by     the original Viterbi POS tagger and got corrected after  modifications.
#  <hr />

# %% [markdown]
# # Steps
# <hr />
#
# 1.   <b> Data Preparation and Exploring the Penn Treebank dataset </b>
#
#
# 2.  <b> Build the vanilla Viterbi based POS tagger </b>
#
#
# 3. <b> Modify Viterbi Heuristic Algorithm to consider only transition probability for UNKNOWN words </b>
#
#
# 4.  <b> Modify Viterbi Heuristic Algorithm to tag UNKNOWN words using rule-based approach  </b>
#
#
# 5.   <b> Evaluate each model on validation data </b>
#
#
# 5.   <b> Compare accuracy of modified models with vanilla Viterbi </b>
#
#
# 6.  <b> Print word tags corrected by modified models </b>
#
#
# 7. <b> Tag the words using these new models in the sample file and compare the results. </b>
#
# <hr />

# %% [markdown]
# ## Data Preparation and EDA

# %%
#Importing libraries
import nltk
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import random
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import pprint, time
from nltk.tokenize import word_tokenize

from collections import Counter

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# first few tagged sentences
print(nltk_data[:5])
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')], [('Rudolph', 'NOUN'), ('Agnew', 'NOUN'), (',', '.'), ('55', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), ('and', 'CONJ'), ('former', 'ADJ'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Consolidated', 'NOUN'), ('Gold', 'NOUN'), ('Fields', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('was', 'VERB'), ('named', 'VERB'), ('*-1', 'X'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('of', 'ADP'), ('this', 'DET'), ('British', 'ADJ'), ('industrial', 'ADJ'), ('conglomerate', 'NOUN'), ('.', '.')], [('A', 'DET'), ('form', 'NOUN'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('once', 'ADV'), ('used', 'VERB'), ('*', 'X'), ('*', 'X'), ('to', 'PRT'), ('make', 'VERB'), ('Kent', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('has', 'VERB'), ('caused', 'VERB'), ('a', 'DET'), ('high', 'ADJ'), ('percentage', 'NOUN'), ('of', 'ADP'), ('cancer', 'NOUN'), ('deaths', 'NOUN'), ('among', 'ADP'), ('a', 'DET'), ('group', 'NOUN'), ('of', 'ADP'), ('workers', 'NOUN'), ('exposed', 'VERB'), ('*', 'X'), ('to', 'PRT'), ('it', 'PRON'), ('more', 'ADV'), ('than', 'ADP'), ('30', 'NUM'), ('years', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('researchers', 'NOUN'), ('reported', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')], [('The', 'DET'), ('asbestos', 'NOUN'), ('fiber', 'NOUN'), (',', '.'), ('crocidolite', 'NOUN'), (',', '.'), ('is', 'VERB'), ('unusually', 'ADV'), ('resilient', 'ADJ'), ('once', 'ADP'), ('it', 'PRON'), ('enters', 'VERB'), ('the', 'DET'), ('lungs', 'NOUN'), (',', '.'), ('with', 'ADP'), ('even', 'ADV'), ('brief', 'ADJ'), ('exposures', 'NOUN'), ('to', 'PRT'), ('it', 'PRON'), ('causing', 'VERB'), ('symptoms', 'NOUN'), ('that', 'DET'), ('*T*-1', 'X'), ('show', 'VERB'), ('up', 'PRT'), ('decades', 'NOUN'), ('later', 'ADJ'), (',', '.'), ('researchers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-2', 'X'), ('.', '.')]]

# %%
# Splitting into train and test
random.seed(1234)
# validation set is 5% of the total dataset
train_set,vald_set = train_test_split(nltk_data,random_state = 42,test_size=0.05)

print(len(train_set))
print(len(vald_set))
# Out:
# 3718
# 196

# %%
train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)
# Out:
# 95589

# %%
# tokens 
tokens = [pair[0] for pair in train_tagged_words]
tokens[:10]
# Out:
# ['Bank', 'of', 'New', 'England', "'s", 'shares', 'are', 'traded', '*-1', 'on']

# %%
# vocabulary
V = set(tokens)
print(len(V))
# Out:
# 12109

# %%
# number of tags
T = set([pair[1] for pair in train_tagged_words])
len(T)
list(T)
# Out:
# ['ADP',
#  'X',
#  'DET',
#  'NUM',
#  'VERB',
#  'PRT',
#  'ADJ',
#  'CONJ',
#  'PRON',
#  'ADV',
#  'NOUN',
#  '.']

# %%
#We notice that there are many words that are assigned to .
dotpair = [pair for pair in train_tagged_words if pair[1]=='.']
Counter(dotpair).most_common(10)
# Out:
# [((',', '.'), 4632),
#  (('.', '.'), 3638),
#  (('``', '.'), 668),
#  (('$', '.'), 667),
#  (("''", '.'), 650),
#  (('--', '.'), 214),
#  ((';', '.'), 171),
#  ((':', '.'), 135),
#  (('-RRB-', '.'), 106),
#  (('-LRB-', '.'), 103)]

# %% [markdown]
# ## Vanilla Viterbi based POS tagger

# %% [markdown]
# ### Emission Probabilities

# %%
# computing P(w/t) and storing in T x V matrix
t = len(T)
v = len(V)
w_given_t = np.zeros((t, v))

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %% [markdown]
# ### Transition Probabilities

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
# convert the matrix to a df for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))
tags_df
# Out:
#            ADP         X       DET       NUM      VERB       PRT       ADJ  \
# ADP   0.017228  0.034029  0.326378  0.062921  0.008240  0.001498  0.105297
# X     0.142925  0.076482  0.055131  0.002709  0.203633  0.185787  0.016571
# DET   0.009054  0.045509  0.005311  0.021970  0.038387  0.000241  0.204973
# NUM   0.034790  0.206661  0.003271  0.184062  0.017544  0.027951  0.034196
# VERB  0.090493  0.218005  0.133101  0.022817  0.169189  0.031121  0.064649
# PRT   0.021576  0.013403  0.100360  0.058516  0.402746  0.001635  0.086303
# ADJ   0.078986  0.021392  0.005101  0.020405  0.012342  0.010861  0.066645
# CONJ  0.054435  0.007977  0.121539  0.042234  0.153918  0.004693  0.116847
# PRON  0.022918  0.092819  0.009549  0.007257  0.480901  0.012223  0.074866
# ADV   0.119601  0.023588  0.067110  0.030565  0.344518  0.013621  0.130233
# NOUN  0.176275  0.029136  0.013310  0.009627  0.147978  0.043832  0.012289
# .     0.091114  0.026623  0.173502  0.080500  0.088505  0.002339  0.044972
#
#           CONJ      PRON       ADV      NOUN         .
# ADP   0.000856  0.069128  0.013162  0.321776  0.039486
# X     0.010357  0.056087  0.025175  0.061345  0.163799
# DET   0.000483  0.003742  0.012313  0.640029  0.017986
# NUM   0.013381  0.001487  0.002974  0.355338  0.118347
# VERB  0.005588  0.036244  0.082577  0.110904  0.035312
# PRT   0.002288  0.018960  0.010134  0.242563  0.041517
# ADJ   0.016949  0.000658  0.004608  0.696725  0.065328
# CONJ  0.000469  0.058658  0.055842  0.349132  0.034256
# PRON  0.004966  0.008021  0.033995  0.211230  0.041253
# ADV   0.006312  0.015615  0.081063  0.030897  0.136877
# NOUN  0.041936  0.004923  0.016884  0.264632  0.239179
# .     0.057924  0.065389  0.052078  0.223152  0.093812

# %%
tags_df.loc['.', :]
# Out:
# ADP     0.091114
# X       0.026623
# DET     0.173502
# NUM     0.080500
# VERB    0.088505
# PRT     0.002339
# ADJ     0.044972
# CONJ    0.057924
# PRON    0.065389
# ADV     0.052078
# NOUN    0.223152
# .       0.093812
# Name: ., dtype: float32

# %%
len(train_tagged_words)
# Out:
# 95589

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
def measure_accuracy(predicted, real):
    check = [i for i, j in zip(predicted, real) if i == j] 
    accuracy = len(check)/len(predicted)
    return accuracy

# %%
def find_incorrect_tags(predicted, real):
    incorrect_tags = [[real[i-1],j] for i, j in enumerate(zip(predicted, real)) if j[0]!=j[1]]
    return incorrect_tags

# %% [markdown]
# ### Evaluating on validation set

# %%
# Running Viterbi algorithm on validation dataset


# list of tagged words
test_run_base = [tup for sent in vald_set for tup in sent]

# list of untagged words
test_tagged_words = [tup[0] for sent in vald_set for tup in sent]

# %%
# tagging the test sentences
start = time.time()
tagged_seq = Viterbi(test_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
# Out:
# Time taken in seconds:  1941.3890435695648

# %%
acc = measure_accuracy(tagged_seq,test_run_base)
print("Accuracy with original Viterbi \t\t{:0.2f} %".format(acc*100))
# Out:
# Accuracy with original Viterbi 		91.47 %

# %%
find_incorrect_tags(tagged_seq, test_run_base)
# Out:
# [[('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('the', 'DET'), (('Overseas', 'ADP'), ('Overseas', 'NOUN'))],
#  [('Overseas', 'NOUN'), (('Private', 'ADJ'), ('Private', 'NOUN'))],
#  [('settled', 'VERB'), (('pre-1917', 'ADP'), ('pre-1917', 'ADJ'))],
#  [('``', '.'), (('Unemployment', 'ADP'), ('Unemployment', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('weekly', 'ADJ'), (('paycheck', 'ADP'), ('paycheck', 'NOUN'))],
#  [('paycheck', 'NOUN'), (('reasonably', 'ADP'), ('reasonably', 'ADV'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('*-1', 'X'), (('Funded', 'ADP'), ('Funded', 'VERB'))],
#  [('from', 'ADP'), (('Tokio', 'ADP'), ('Tokio', 'NOUN'))],
#  [('medical', 'ADJ'), (('protocols', 'ADP'), ('protocols', 'NOUN'))],
#  [('on', 'ADP'), (('preventative', 'ADP'), ('preventative', 'ADJ'))],
#  [('it', 'PRON'), (('existed', 'ADP'), ('existed', 'VERB'))],
#  [('$', '.'), (('20.5', 'ADP'), ('20.5', 'NUM'))],
#  [('become', 'VERB'), (('polarized', 'ADP'), ('polarized', 'VERB'))],
#  [(',', '.'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('*ICH*-2', 'X'), (('exists', 'ADP'), ('exists', 'VERB'))],
#  [('a', 'DET'), (('middle', 'NOUN'), ('middle', 'ADJ'))],
#  [('prospective', 'ADJ'), (('acquirers', 'ADP'), ('acquirers', 'NOUN'))],
#  [("n't", 'ADV'), (('noticed', 'ADP'), ('noticed', 'VERB'))],
#  [('totaled', 'VERB'), (('154.2', 'ADP'), ('154.2', 'NUM'))],
#  [('Since', 'ADP'), (('chalk', 'ADP'), ('chalk', 'NOUN'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', 'ADP'), ('touched', 'VERB'))],
#  [('touched', 'VERB'), (('slate', 'ADP'), ('slate', 'NOUN'))],
#  [(',', '.'), (('schoolchildren', 'ADP'), ('schoolchildren', 'NOUN'))],
#  [('a', 'DET'), (('Catch-22', 'ADP'), ('Catch-22', 'NOUN'))],
#  [('on', 'ADP'), (('cross-border', 'ADP'), ('cross-border', 'ADJ'))],
#  [('of', 'ADP'), (('emigres', 'ADP'), ('emigres', 'NOUN'))],
#  [('which', 'DET'), (('*T*-133', 'ADP'), ('*T*-133', 'X'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [(',', '.'), (('safe', 'ADP'), ('safe', 'ADJ'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('publicly', 'ADV'), (('apologizing', 'ADP'), ('apologizing', 'VERB'))],
#  [('*', 'X'), (('indulging', 'ADP'), ('indulging', 'VERB'))],
#  [('From', 'ADP'), (('1953', 'ADP'), ('1953', 'NUM'))],
#  [('to', 'PRT'), (('1955', 'ADP'), ('1955', 'NUM'))],
#  [('the', 'DET'), (('homeless', 'ADJ'), ('homeless', 'NOUN'))],
#  [('had', 'VERB'), (('pre-existing', 'ADP'), ('pre-existing', 'ADJ'))],
#  [('or', 'CONJ'), (('addiction', 'ADP'), ('addiction', 'NOUN'))],
#  [('gaining', 'VERB'), (('1,200', 'ADP'), ('1,200', 'NUM'))],
#  [('Jack', 'NOUN'), (('Mogavero', 'ADP'), ('Mogavero', 'NOUN'))],
#  [(',', '.'), (('Piscataway', 'ADP'), ('Piscataway', 'NOUN'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('to', 'PRT'), (('American-style', 'ADP'), ('American-style', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-253', 'ADP'), ('*T*-253', 'X'))],
#  [('to', 'PRT'), (('exploit', 'ADP'), ('exploit', 'VERB'))],
#  [('great', 'ADJ'), (('reds', 'ADP'), ('reds', 'NOUN'))],
#  [('the', 'DET'), (('Rhone', 'ADP'), ('Rhone', 'NOUN'))],
#  [('price', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('$', '.'), (('133.7', 'ADP'), ('133.7', 'NUM'))],
#  [('$', '.'), (('94', 'ADP'), ('94', 'NUM'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('she', 'PRON'), (('copied', 'ADP'), ('copied', 'VERB'))],
#  [('two', 'NUM'), (('octogenarians', 'ADP'), ('octogenarians', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-222', 'ADP'), ('*T*-222', 'X'))],
#  [('a', 'DET'),
#   (('sometimes-exhausting', 'ADP'), ('sometimes-exhausting', 'ADJ'))],
#  [('bells', 'NOUN'), (('sounding', 'ADP'), ('sounding', 'VERB'))],
#  [('many', 'ADJ'), (('belfries', 'ADP'), ('belfries', 'NOUN'))],
#  [('East', 'NOUN'), (('Anglia', 'ADP'), ('Anglia', 'NOUN'))],
#  [('of', 'ADP'), (('manmade-fiber', 'ADP'), ('manmade-fiber', 'ADJ'))],
#  [('$', '.'), (('405', 'ADP'), ('405', 'NUM'))],
#  [('What', 'PRON'), (('*T*-102', 'ADP'), ('*T*-102', 'X'))],
#  [('*T*-102', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('Maxwell', 'NOUN'), (('Communication', 'ADP'), ('Communication', 'NOUN'))],
#  [('net', 'ADJ'), (('importer', 'ADP'), ('importer', 'NOUN'))],
#  [('to', 'PRT'), (('last', 'ADJ'), ('last', 'VERB'))],
#  [('ShareData', 'NOUN'), (('develops', 'ADP'), ('develops', 'VERB'))],
#  [('and', 'CONJ'), (('markets', 'NOUN'), ('markets', 'VERB'))],
#  [('markets', 'VERB'), (('low-cost', 'ADP'), ('low-cost', 'ADJ'))],
#  [('House', 'NOUN'), (('waived', 'ADP'), ('waived', 'VERB'))],
#  [('in', 'ADP'), (('supplemental', 'ADP'), ('supplemental', 'ADJ'))],
#  [('and', 'CONJ'), (('anti-drug', 'ADP'), ('anti-drug', 'ADJ'))],
#  [('no', 'DET'), (('bearing', 'VERB'), ('bearing', 'NOUN'))],
#  [('our', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('before', 'ADP'), (('that', 'DET'), ('that', 'ADP'))],
#  [('a', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('to', 'PRT'), (('red-flag', 'ADP'), ('red-flag', 'VERB'))],
#  [('who', 'PRON'), (('*T*-128', 'ADP'), ('*T*-128', 'X'))],
#  [('who', 'PRON'), (('*T*-129', 'ADP'), ('*T*-129', 'X'))],
#  [('the', 'DET'),
#   (('computer-generated', 'ADP'), ('computer-generated', 'ADJ'))],
#  [('by', 'ADP'), (('certified', 'ADP'), ('certified', 'ADJ'))],
#  [('certified', 'ADJ'), (('mail', 'ADP'), ('mail', 'NOUN'))],
#  [('to', 'PRT'), (('veto', 'NOUN'), ('veto', 'VERB'))],
#  [('bills', 'NOUN'), (('containing', 'ADP'), ('containing', 'VERB'))],
#  [(',', '.'), (('alternatively', 'ADP'), ('alternatively', 'ADV'))],
#  [('to', 'PRT'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('their', 'PRON'), (('intrusions', 'ADP'), ('intrusions', 'NOUN'))],
#  [('on', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('thus', 'ADV'), (('void', 'ADP'), ('void', 'ADJ'))],
#  [('R.', 'NOUN'), (('Sloan', 'ADP'), ('Sloan', 'NOUN'))],
#  [(',', '.'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('$', '.'), (('43.875', 'ADP'), ('43.875', 'NUM'))],
#  [("n't", 'ADV'), (('mind', 'NOUN'), ('mind', 'VERB'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('and', 'CONJ'), (('shopped', 'ADP'), ('shopped', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('also', 'ADV'), (('helps', 'ADP'), ('helps', 'VERB'))],
#  [('the', 'DET'), (('reluctance', 'ADP'), ('reluctance', 'NOUN'))],
#  [('farm', 'NOUN'), (('lobbies', 'ADP'), ('lobbies', 'NOUN'))],
#  [('daily', 'ADJ'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [('of', 'ADP'), (('133.8', 'ADP'), ('133.8', 'NUM'))],
#  [('$', '.'), (('2.47', 'ADP'), ('2.47', 'NUM'))],
#  [('up', 'ADV'), (('7.4', 'ADP'), ('7.4', 'NUM'))],
#  [('$', '.'), (('2.30', 'ADP'), ('2.30', 'NUM'))],
#  [('final', 'ADJ'), (('modification', 'ADP'), ('modification', 'NOUN'))],
#  [('made', 'VERB'), (('*-130', 'ADP'), ('*-130', 'X'))],
#  [('five-point', 'ADJ'), (('opening', 'NOUN'), ('opening', 'VERB'))],
#  [('$', '.'), (('13.625', 'ADP'), ('13.625', 'NUM'))],
#  [('*-37', 'X'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('power', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('wield', 'ADP'), ('wield', 'VERB'))],
#  [('.', '.'), (('Muzzling', 'ADP'), ('Muzzling', 'ADJ'))],
#  [('``', '.'), (('blindfold', 'ADP'), ('blindfold', 'NOUN'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('*-2', 'X'), (('recommending', 'ADP'), ('recommending', 'VERB'))],
#  [('``', '.'), (('Anything', 'ADP'), ('Anything', 'NOUN'))],
#  [('Anything', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('how', 'ADV'), (('about', 'ADP'), ('about', 'PRT'))],
#  [("''", '.'), (('quips', 'ADP'), ('quips', 'VERB'))],
#  [('of', 'ADP'), (('Northampton', 'ADP'), ('Northampton', 'NOUN'))],
#  [('morphogenetic', 'ADJ'), (('protein', 'ADP'), ('protein', 'NOUN'))],
#  [('.', '.'), (('Fundamentalists', 'ADP'), ('Fundamentalists', 'NOUN'))],
#  [('including', 'VERB'), (('air', 'VERB'), ('air', 'NOUN'))],
#  [('air', 'NOUN'), (('bags', 'ADP'), ('bags', 'NOUN'))],
#  [('in', 'ADP'), (('front', 'NOUN'), ('front', 'ADJ'))],
#  [('improved', 'VERB'), (('side-crash', 'ADP'), ('side-crash', 'ADJ'))],
#  [('for', 'ADP'), (('alleged', 'ADJ'), ('alleged', 'VERB'))],
#  [('alleged', 'VERB'), (('workplace', 'ADP'), ('workplace', 'NOUN'))],
#  [('a', 'DET'), (('word-processing', 'ADP'), ('word-processing', 'NOUN'))],
#  [('*', 'X'), (('Legend', 'ADP'), ('Legend', 'NOUN'))],
#  [('of', 'ADP'), (('multinational', 'ADP'), ('multinational', 'ADJ'))],
#  [('the', 'DET'), (('Iran-Contra', 'ADP'), ('Iran-Contra', 'NOUN'))],
#  [('a', 'DET'), (('wheel-loader', 'ADP'), ('wheel-loader', 'ADJ'))],
#  [('in', 'ADP'), (('Heidelberg', 'ADP'), ('Heidelberg', 'NOUN'))],
#  [(',', '.'), (('drink', 'NOUN'), ('drink', 'VERB'))],
#  [('and', 'CONJ'), (('desultory', 'ADP'), ('desultory', 'ADJ'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('Yeargin', 'NOUN'), (('distinguished', 'ADP'), ('distinguished', 'VERB'))],
#  [('distinguished', 'VERB'), (('herself', 'ADP'), ('herself', 'PRON'))],
#  [('teaching', 'NOUN'), (('approaches', 'ADP'), ('approaches', 'NOUN'))],
#  [('*-1', 'X'), (('forcing', 'VERB'), ('forcing', 'ADJ'))],
#  [('to', 'PRT'), (('pair', 'ADP'), ('pair', 'VERB'))],
#  [('pair', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('using', 'VERB'), (('college-bowl', 'ADP'), ('college-bowl', 'NOUN'))],
#  [('type', 'NOUN'), (('competitions', 'ADP'), ('competitions', 'NOUN'))],
#  [('international', 'ADJ'), (('coffee', 'ADP'), ('coffee', 'NOUN'))],
#  [('Also', 'ADV'), (('spurring', 'ADP'), ('spurring', 'VERB'))],
#  [('diaper', 'NOUN'), (('covers', 'VERB'), ('covers', 'NOUN'))],
#  [('with', 'ADP'), (('Velcro', 'ADP'), ('Velcro', 'NOUN'))],
#  [('fasteners', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('safety', 'NOUN'), (('pins', 'VERB'), ('pins', 'NOUN'))],
#  [('their', 'PRON'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('and', 'CONJ'), (('finance', 'NOUN'), ('finance', 'VERB'))],
#  [('selling', 'VERB'), (('non-core', 'ADP'), ('non-core', 'ADJ'))],
#  [('it', 'PRON'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('and', 'CONJ'), (('platinum', 'ADP'), ('platinum', 'NOUN'))],
#  [('have', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('was', 'VERB'), (('appropriated', 'ADP'), ('appropriated', 'VERB'))],
#  [('--', '.'), (('twice', 'ADP'), ('twice', 'ADV'))],
#  [('twice', 'ADV'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('a', 'DET'), (('Johnson-era', 'ADP'), ('Johnson-era', 'NOUN'))],
#  [('creation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-2', 'X'), (('mandates', 'ADP'), ('mandates', 'VERB'))],
#  [('*-1', 'X'), (('noncompetitively', 'ADP'), ('noncompetitively', 'ADV'))],
#  [('very', 'ADV'), (('concerned', 'ADP'), ('concerned', 'VERB'))],
#  [('*T*-1', 'X'), (('Wilfred', 'ADP'), ('Wilfred', 'NOUN'))],
#  [('J.', 'NOUN'), (('Corrigan', 'ADP'), ('Corrigan', 'NOUN'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('chief', 'ADJ'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('take', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('``', '.'), (('derivatives', 'ADP'), ('derivatives', 'NOUN'))],
#  [('times', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('underlying', 'ADJ'), ('underlying', 'VERB'))],
#  [('adding', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [("'", 'PRT'), (('binders', 'ADP'), ('binders', 'NOUN'))],
#  [('$', '.'), (('93.9', 'ADP'), ('93.9', 'NUM'))],
#  [('$', '.'), (('1.19', 'ADP'), ('1.19', 'NUM'))],
#  [('$', '.'), (('92.9', 'ADP'), ('92.9', 'NUM'))],
#  [('$', '.'), (('1.18', 'ADP'), ('1.18', 'NUM'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('.', '.'), (('Demand', 'ADP'), ('Demand', 'NOUN'))],
#  [('but', 'CONJ'), (('due', 'ADJ'), ('due', 'ADV'))],
#  [(',', '.'), (('overseas', 'ADV'), ('overseas', 'ADJ'))],
#  [('the', 'DET'), (('apparent', 'ADP'), ('apparent', 'ADJ'))],
#  [('David', 'NOUN'), (('Berson', 'ADP'), ('Berson', 'NOUN'))],
#  [('on', 'ADP'), (('single-family', 'NOUN'), ('single-family', 'ADJ'))],
#  [("n't", 'ADV'), (('estimate', 'NOUN'), ('estimate', 'VERB'))],
#  [('a', 'DET'), (('razor-thin', 'ADP'), ('razor-thin', 'ADJ'))],
#  [('a', 'DET'), (('fledgling', 'ADP'), ('fledgling', 'NOUN'))],
#  [('to', 'PRT'), (('depend', 'ADP'), ('depend', 'VERB'))],
#  [('and', 'CONJ'), (('longevity', 'ADP'), ('longevity', 'NOUN'))],
#  [('IRS', 'NOUN'), (('rarely', 'ADP'), ('rarely', 'ADV'))],
#  [('rarely', 'ADV'), (('acted', 'ADP'), ('acted', 'VERB'))],
#  [('``', '.'), (('deplorable', 'ADP'), ('deplorable', 'ADJ'))],
#  [('but', 'CONJ'), (('brushed', 'ADP'), ('brushed', 'VERB'))],
#  [('brushed', 'VERB'), (('off', 'ADJ'), ('off', 'PRT'))],
#  [('*', 'X'), (('renewing', 'ADP'), ('renewing', 'VERB'))],
#  [('the', 'DET'), (('insurgents', 'ADP'), ('insurgents', 'NOUN'))],
#  [('0', 'X'), (('total', 'VERB'), ('total', 'ADJ'))],
#  [('were', 'VERB'), (('topped', 'ADP'), ('topped', 'VERB'))],
#  [('the', 'DET'), (('16.5', 'ADP'), ('16.5', 'NUM'))],
#  [('contradict', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('-LRB-', '.'), (('technically', 'ADP'), ('technically', 'ADV'))],
#  [('a', 'DET'), (('limitation', 'ADP'), ('limitation', 'NOUN'))],
#  [('short', 'ADJ'), (('leash', 'ADP'), ('leash', 'NOUN'))],
#  [('.', '.'), (('No', 'DET'), ('No', 'ADV'))],
#  [(',', '.'), (('triple', 'ADP'), ('triple', 'ADV'))],
#  [('a', 'DET'), (('Washington-based', 'ADP'), ('Washington-based', 'ADJ'))],
#  [('to', 'PRT'), (('sue', 'ADP'), ('sue', 'VERB'))],
#  [('$', '.'), (('777', 'ADP'), ('777', 'NUM'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('rose', 'VERB'), (('1.20', 'ADP'), ('1.20', 'NUM'))],
#  [('$', '.'), (('1.14', 'ADP'), ('1.14', 'NUM'))],
#  [('considerable', 'ADJ'), (('skill', 'ADP'), ('skill', 'NOUN'))],
#  [('of', 'ADP'), (('2163.2', 'ADP'), ('2163.2', 'NUM'))],
#  [('last', 'ADJ'), (('half-hour', 'ADJ'), ('half-hour', 'NOUN'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('Lane', 'NOUN'), (('dreamed', 'ADP'), ('dreamed', 'VERB'))],
#  [('dreamed', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('highly', 'ADV'), (('improbable', 'ADP'), ('improbable', 'ADJ'))],
#  [("'s", 'PRT'), (('shop', 'ADP'), ('shop', 'NOUN'))],
#  [('expensive', 'ADJ'), (('high-rise', 'ADP'), ('high-rise', 'ADJ'))],
#  [('Oct.', 'NOUN'), (('2-8', 'ADP'), ('2-8', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('to', 'PRT'), (('A.C.', 'ADP'), ('A.C.', 'NOUN'))],
#  [('A.C.', 'NOUN'), (('Nielsen', 'ADP'), ('Nielsen', 'NOUN'))],
#  [('*', 'X'), (('Having', 'ADP'), ('Having', 'VERB'))],
#  [('a', 'DET'), (('supportive', 'ADP'), ('supportive', 'ADJ'))],
#  [('supportive', 'ADJ'), (('element', 'ADP'), ('element', 'NOUN'))],
#  [('Richard', 'NOUN'), (('Breeden', 'ADP'), ('Breeden', 'NOUN'))],
#  [('circuit', 'NOUN'), (('breakers', 'ADP'), ('breakers', 'NOUN'))],
#  [('that', 'DET'), (('*T*-215', 'ADP'), ('*T*-215', 'X'))],
#  [('rose', 'VERB'), (('87.5', 'ADP'), ('87.5', 'NUM'))],
#  [('$', '.'), (('38.875', 'ADP'), ('38.875', 'NUM'))],
#  [('frozen', 'VERB'), (('noodles', 'ADP'), ('noodles', 'NOUN'))],
#  [('and', 'CONJ'), (('pre-cooked', 'ADP'), ('pre-cooked', 'ADJ'))],
#  [('pre-cooked', 'ADJ'), (('pasta', 'ADP'), ('pasta', 'NOUN'))],
#  [('in', 'ADP'), (('Clive', 'ADP'), ('Clive', 'NOUN'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('P.', 'NOUN'), (('Smaby', 'ADP'), ('Smaby', 'NOUN'))],
#  [('of', 'ADP'), (('Smaby', 'ADP'), ('Smaby', 'NOUN'))],
#  [('questionable', 'ADJ'), (('properties', 'ADP'), ('properties', 'NOUN'))],
#  [('.', '.'), (('INTER-TEL', 'ADP'), ('INTER-TEL', 'NOUN'))],
#  [('a', 'DET'), (('cosmetic', 'NOUN'), ('cosmetic', 'ADJ'))],
#  [('S.', 'NOUN'), (('Gelles', 'ADP'), ('Gelles', 'NOUN'))],
#  [('of', 'ADP'), (('Wertheim', 'ADP'), ('Wertheim', 'NOUN'))],
#  [('Wertheim', 'NOUN'), (('Schroder', 'ADP'), ('Schroder', 'NOUN'))],
#  [('and', 'CONJ'), (('entertaining', 'ADP'), ('entertaining', 'ADJ'))],
#  [('that', 'DET'), (('means', 'NOUN'), ('means', 'VERB'))],
#  [('means', 'VERB'), (('confrontational', 'ADP'), ('confrontational', 'ADJ'))],
#  [('be', 'VERB'), (('refunded', 'ADP'), ('refunded', 'VERB'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'ADP'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'ADP'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'ADP'), ('suitors', 'NOUN'))],
#  [('you', 'PRON'), (('bothered', 'ADP'), ('bothered', 'VERB'))],
#  [('the', 'DET'), (('inverse', 'ADP'), ('inverse', 'NOUN'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('on', 'ADP'), (('66.5', 'ADP'), ('66.5', 'NUM'))],
#  [('factors', 'NOUN'), (('affecting', 'ADP'), ('affecting', 'VERB'))],
#  [('Anthony', 'NOUN'), (('Hazell', 'ADP'), ('Hazell', 'NOUN'))],
#  [('district', 'NOUN'), (('auditor', 'ADP'), ('auditor', 'NOUN'))],
#  [("n't", 'ADV'), (('vested', 'ADP'), ('vested', 'VERB'))],
#  [('of', 'ADP'), (('seconds', 'ADP'), ('seconds', 'NOUN'))],
#  [('a', 'DET'), (('low-tech', 'ADP'), ('low-tech', 'ADJ'))],
#  [('can', 'VERB'), (('catch', 'NOUN'), ('catch', 'VERB'))],
#  [("'s", 'PRT'), (('fancy', 'ADP'), ('fancy', 'NOUN'))],
#  [('a', 'DET'), (('strategic', 'ADP'), ('strategic', 'ADJ'))],
#  [('strategic', 'ADJ'), (('fit', 'ADJ'), ('fit', 'NOUN'))],
#  [('*', 'X'), (('servicing', 'NOUN'), ('servicing', 'VERB'))],
#  [('opportunities', 'NOUN'), (('arise', 'ADP'), ('arise', 'VERB'))],
#  [('a', 'DET'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('or', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('more', 'ADV'), (('cumbersome', 'ADP'), ('cumbersome', 'ADJ'))],
#  [('wild', 'ADJ'), (('stock-price', 'ADP'), ('stock-price', 'NOUN'))],
#  [(':', '.'), (('day-care', 'ADP'), ('day-care', 'ADJ'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('previously', 'ADV'), (('spurned', 'ADP'), ('spurned', 'VERB'))],
#  [('those', 'DET'), (('pressed', 'ADP'), ('pressed', 'VERB'))],
#  [('are', 'VERB'), (('implemented', 'ADP'), ('implemented', 'VERB'))],
#  [(':', '.'), (('1', 'NUM'), ('1', 'X'))],
#  [(',', '.'), (('2', 'NUM'), ('2', 'X'))],
#  [('investment', 'NOUN'), (('focus', 'VERB'), ('focus', 'NOUN'))],
#  [('and', 'CONJ'), (('3', 'NUM'), ('3', 'X'))],
#  [('level', 'NOUN'), (('playing', 'VERB'), ('playing', 'NOUN'))],
#  [('their', 'PRON'), (('monopoly', 'ADP'), ('monopoly', 'NOUN'))],
#  [('yield', 'VERB'), (('7.422', 'ADP'), ('7.422', 'NUM'))],
#  [('So', 'ADV'), (('crunch', 'ADP'), ('crunch', 'NOUN'))],
#  [(',', '.'), (('crunch', 'ADP'), ('crunch', 'NOUN'))],
#  [(',', '.'), (('crunch', 'ADP'), ('crunch', 'NOUN'))],
#  [(',', '.'), (('bang', 'ADP'), ('bang', 'NOUN'))],
#  [(',', '.'), (('bang', 'ADP'), ('bang', 'NOUN'))],
#  [(',', '.'), (('bang', 'ADP'), ('bang', 'NOUN'))],
#  [('from', 'ADP'), (('above', 'ADP'), ('above', 'ADV'))],
#  [('very', 'ADV'), (('obvious', 'ADP'), ('obvious', 'ADJ'))],
#  [('obvious', 'ADJ'), (('exit', 'ADP'), ('exit', 'NOUN'))],
#  [('at', 'ADP'), (('prayer', 'ADP'), ('prayer', 'NOUN'))],
#  [('has', 'VERB'), (('minted', 'ADP'), ('minted', 'VERB'))],
#  [('of', 'ADP'), (('millionaires', 'ADP'), ('millionaires', 'NOUN'))],
#  [('their', 'PRON'), (('20s', 'ADP'), ('20s', 'NUM'))],
#  [('and', 'CONJ'), (('30s', 'ADP'), ('30s', 'NUM'))],
#  [('in', 'ADP'), (('replacement-car', 'ADP'), ('replacement-car', 'NOUN'))],
#  [('replacement-car', 'NOUN'), (('rentals', 'ADP'), ('rentals', 'NOUN'))],
#  [('in', 'ADP'), (('accidents', 'ADP'), ('accidents', 'NOUN'))],
#  [('for', 'ADP'),
#   (('computer-system-design', 'ADP'), ('computer-system-design', 'ADJ'))],
#  [('the', 'DET'), (('more-advanced', 'ADP'), ('more-advanced', 'ADJ'))],
#  [('386', 'NUM'), (('microprocessor', 'ADP'), ('microprocessor', 'NOUN'))],
#  [('four', 'NUM'), (('megabytes', 'ADP'), ('megabytes', 'NOUN'))],
#  [('a', 'DET'), (('100-megabyte', 'ADP'), ('100-megabyte', 'ADJ'))],
#  [('$', '.'), (('5,699', 'ADP'), ('5,699', 'NUM'))],
#  [('$', '.'), (('6,799', 'ADP'), ('6,799', 'NUM'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'ll", 'VERB'), (('weather', 'NOUN'), ('weather', 'VERB'))],
#  [('any', 'DET'), (('storm', 'ADP'), ('storm', 'NOUN'))],
#  [("''", '.'), (('Citizens', 'ADP'), ('Citizens', 'NOUN'))],
#  [('in', 'ADP'), (('Peninsula', 'ADP'), ('Peninsula', 'NOUN'))],
#  [("'s", 'PRT'), (('floral', 'ADP'), ('floral', 'ADJ'))],
#  [('$', '.'), (('70-a-share', 'ADP'), ('70-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('buy-back', 'NOUN'), ('buy-back', 'ADJ'))],
#  [('*-2', 'X'), (('pressed', 'ADP'), ('pressed', 'VERB'))],
#  [('which', 'DET'), (('*T*-156', 'ADP'), ('*T*-156', 'X'))],
#  [('earlier', 'ADJ'), (('tender', 'NOUN'), ('tender', 'ADJ'))],
#  [('still', 'ADV'), (('concerned', 'ADP'), ('concerned', 'VERB'))],
#  [('disturbing', 'ADJ'), (('developments', 'ADP'), ('developments', 'NOUN'))],
#  [('continuing', 'VERB'), (('slow', 'VERB'), ('slow', 'ADJ'))],
#  [('*T*-42', 'X'), (('saved', 'ADP'), ('saved', 'VERB'))],
#  [('to', 'PRT'), (('reclaim', 'ADP'), ('reclaim', 'VERB'))],
#  [('``', '.'), (('mortgaged', 'ADP'), ('mortgaged', 'VERB'))],
#  [('under', 'ADP'), (('price-support', 'ADP'), ('price-support', 'ADJ'))],
#  [('latest', 'ADJ'), (('compilation', 'ADP'), ('compilation', 'NOUN'))],
#  [('open', 'ADJ'),
#   (('direct-investment', 'ADP'), ('direct-investment', 'ADJ'))],
#  [('he', 'PRON'), (('blames', 'ADP'), ('blames', 'VERB'))],
#  [('an', 'DET'), (('actor', 'ADP'), ('actor', 'NOUN'))],
#  [('the', 'DET'), (('inheritor', 'ADP'), ('inheritor', 'NOUN'))],
#  [('of', 'ADP'), (('Charlie', 'ADP'), ('Charlie', 'NOUN'))],
#  [("'s", 'PRT'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('not', 'ADV'), (('volunteer', 'ADP'), ('volunteer', 'NOUN'))],
#  [('--', '.'), (('teetering', 'ADP'), ('teetering', 'VERB'))],
#  [('on', 'ADP'), (('insolvency', 'ADP'), ('insolvency', 'NOUN'))],
#  [('a', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('reported', 'VERB'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('better', 'ADJ'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('an', 'DET'), (('avid', 'ADP'), ('avid', 'ADJ'))],
#  [('avid', 'ADJ'), (('fan', 'ADP'), ('fan', 'NOUN'))],
#  [('Toronto', 'NOUN'), (('cable', 'ADP'), ('cable', 'NOUN'))],
#  [('People', 'NOUN'), (('close', 'VERB'), ('close', 'ADJ'))],
#  [('to', 'PRT'), (('guarantee', 'NOUN'), ('guarantee', 'VERB'))],
#  [('estimated', 'VERB'),
#   (('seven-million-ton', 'ADP'), ('seven-million-ton', 'ADJ'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('acid', 'ADJ'), ('acid', 'NOUN'))],
#  [('on', 'ADP'), (('50.1', 'ADP'), ('50.1', 'NUM'))],
#  [('A.', 'NOUN'), (('DiLoreto', 'ADP'), ('DiLoreto', 'NOUN'))],
#  [('metal', 'NOUN'), (('container', 'ADP'), ('container', 'NOUN'))],
#  [('succeeding', 'VERB'), (('Delmont', 'ADP'), ('Delmont', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('.', '.'), (('FreudToy', 'ADP'), ('FreudToy', 'NOUN'))],
#  [('a', 'DET'), (('pillow', 'ADP'), ('pillow', 'NOUN'))],
#  [('the', 'DET'), (('likeness', 'ADP'), ('likeness', 'NOUN'))],
#  [('of', 'ADP'), (('Sigmund', 'ADP'), ('Sigmund', 'NOUN'))],
#  [('Sigmund', 'NOUN'), (('Freud', 'ADP'), ('Freud', 'NOUN'))],
#  [('$', '.'), (('24.95', 'ADP'), ('24.95', 'NUM'))],
#  [('*U*', 'X'), (('tool', 'ADP'), ('tool', 'NOUN'))],
#  [('for', 'ADP'), (('do-it-yourself', 'ADP'), ('do-it-yourself', 'ADJ'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('$', '.'), (('1.82', 'ADP'), ('1.82', 'NUM'))],
#  [('$', '.'), (('84.29', 'ADP'), ('84.29', 'NUM'))],
#  [('the', 'DET'), (('impending', 'VERB'), ('impending', 'ADJ'))],
#  [('impending', 'ADJ'), (('attack', 'VERB'), ('attack', 'NOUN'))],
#  [("n't", 'ADV'), (('enough', 'ADV'), ('enough', 'ADJ'))],
#  [('ring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('a', 'DET'), (('longtime', 'ADP'), ('longtime', 'NOUN'))],
#  [('a', 'DET'), (('scholar', 'ADP'), ('scholar', 'NOUN'))],
#  [('rumored', 'VERB'), (('target', 'VERB'), ('target', 'NOUN'))],
#  [('been', 'VERB'), (('enormously', 'ADP'), ('enormously', 'ADV'))],
#  [('enormously', 'ADV'), (('frustrating', 'ADP'), ('frustrating', 'VERB'))],
#  [('computer', 'NOUN'), (('science', 'ADP'), ('science', 'NOUN'))],
#  [('was', 'VERB'), (('raring', 'ADP'), ('raring', 'ADJ'))],
#  [('to', 'PRT'), (('invent', 'ADP'), ('invent', 'VERB'))],
#  [('another', 'DET'), (('Walkman', 'ADP'), ('Walkman', 'NOUN'))],
#  [('--', '.'), (('IRAs', 'ADP'), ('IRAs', 'NOUN'))],
#  [("n't", 'ADV'), (('segmenting', 'ADP'), ('segmenting', 'VERB'))],
#  [('to', 'PRT'), (('equip', 'ADP'), ('equip', 'VERB'))],
#  [('with', 'ADP'), (('lap-shoulder', 'ADP'), ('lap-shoulder', 'ADJ'))],
#  [('for', 'ADP'), (('rear', 'ADP'), ('rear', 'ADJ'))],
#  [('was', 'VERB'), (('soliciting', 'ADP'), ('soliciting', 'VERB'))],
#  [('sell', 'VERB'), (('TXO', 'ADP'), ('TXO', 'NOUN'))],
#  [('free', 'ADJ'), (('trip', 'ADP'), ('trip', 'NOUN'))],
#  [('*-5', 'X'), (('mindful', 'ADP'), ('mindful', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('from', 'ADP'), (('malignant', 'ADP'), ('malignant', 'ADJ'))],
#  [('malignant', 'ADJ'), (('mesothelioma', 'ADP'), ('mesothelioma', 'NOUN'))],
#  [('and', 'CONJ'), (('asbestosis', 'ADP'), ('asbestosis', 'NOUN'))],
#  [(',', '.'), (('16.9', 'ADP'), ('16.9', 'NUM'))],
#  [('0', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('with', 'ADP'), (('17.4', 'ADP'), ('17.4', 'NUM'))],
#  [('and', 'CONJ'), (('18.6', 'ADP'), ('18.6', 'NUM'))],
#  [('.', '.'), (('Tokyu', 'ADP'), ('Tokyu', 'NOUN'))],
#  [('the', 'DET'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('the', 'DET'), (('verge', 'ADP'), ('verge', 'NOUN'))],
#  [('most', 'ADV'), (('favored', 'VERB'), ('favored', 'ADJ'))],
#  [('abortionist', 'NOUN'), (('accidentally', 'ADP'), ('accidentally', 'ADV'))],
#  [('it', 'PRON'), (('enabled', 'ADP'), ('enabled', 'VERB'))],
#  [('buy', 'VERB'), (('jam', 'ADP'), ('jam', 'NOUN'))],
#  [(',', '.'), (('cocoa', 'ADP'), ('cocoa', 'NOUN'))],
#  [('other', 'ADJ'), (('war-rationed', 'ADP'), ('war-rationed', 'ADJ'))],
#  [('war-rationed', 'ADJ'), (('goodies', 'ADP'), ('goodies', 'NOUN'))],
#  [('the', 'DET'), (('reins', 'ADP'), ('reins', 'NOUN'))],
#  [('have', 'VERB'), (('competed', 'ADP'), ('competed', 'VERB'))],
#  [('and', 'CONJ'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('would', 'VERB'), (('disclose', 'ADP'), ('disclose', 'VERB'))],
#  [("'s", 'PRT'), (('cost', 'VERB'), ('cost', 'NOUN'))],
#  [('$', '.'), (('1.50', 'ADP'), ('1.50', 'NUM'))],
#  [('Henry', 'NOUN'), (('I.', 'ADP'), ('I.', 'NOUN'))],
#  [('alleged', 'ADJ'), (('improper', 'ADP'), ('improper', 'ADJ'))],
#  [('to', 'PRT'), (('crack', 'NOUN'), ('crack', 'VERB'))],
#  [('crack', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('January', 'NOUN'), (('platinum', 'ADP'), ('platinum', 'NOUN'))],
#  [('was', 'VERB'), (('down', 'ADV'), ('down', 'ADP'))],
#  [('$', '.'), (('5.70', 'ADP'), ('5.70', 'NUM'))],
#  [('$', '.'), (('494.50', 'ADP'), ('494.50', 'NUM'))]]

# %%
tagged_seq
# Out:
# [('For', 'ADP'),
#  ('the', 'DET'),
#  ('Agency', 'NOUN'),
#  ('for', 'ADP'),
#  ('International', 'NOUN'),
#  ('Development', 'NOUN'),
#  (',', '.'),
#  ('appropriators', 'NOUN'),
#  ('approved', 'VERB'),
#  ('$', '.'),
#  ('200', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('secondary', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('under', 'ADP'),
#  ('an', 'DET'),
#  ('expanded', 'VERB'),
#  ('trade', 'VERB'),
#  ('credit', 'NOUN'),
#  ('insurance', 'NOUN'),
#  ('program', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('total', 'ADJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('for', 'ADP'),
#  ('the', 'DET'),
#  ('Overseas', 'ADP'),
#  ('Private', 'ADJ'),
#  ('Investment', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('are', 'VERB'),
#  ('increased', 'VERB'),
#  ('*-3', 'X'),
#  ('by', 'ADP'),
#  ('$', '.'),
#  ('40', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('over', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1989', 'NUM'),
#  ('as', 'ADP'),
#  ('part', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('Poland', 'NOUN'),
#  ('package', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('market', 'NOUN'),
#  ('is', 'VERB'),
#  ('just', 'ADV'),
#  ('becoming', 'VERB'),
#  ('more', 'ADV'),
#  ('efficient', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Moscow', 'NOUN'),
#  ('has', 'VERB'),
#  ('settled', 'VERB'),
#  ('pre-1917', 'ADP'),
#  ('debts', 'NOUN'),
#  ('with', 'ADP'),
#  ('other', 'ADJ'),
#  ('countries', 'NOUN'),
#  ('in', 'ADP'),
#  ('recent', 'ADJ'),
#  ('years', 'NOUN'),
#  ('at', 'ADP'),
#  ('less', 'ADJ'),
#  ('than', 'ADP'),
#  ('face', 'NOUN'),
#  ('value', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Unemployment', 'ADP'),
#  ('continues', 'VERB'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('relatively', 'ADV'),
#  ('low', 'ADJ'),
#  ('level', 'NOUN'),
#  (',', '.'),
#  ('*', 'X'),
#  ('providing', 'VERB'),
#  ('a', 'DET'),
#  ('sense', 'NOUN'),
#  ('of', 'ADP'),
#  ('job', 'NOUN'),
#  ('security', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('low', 'ADJ'),
#  ('inflation', 'NOUN'),
#  ('rate', 'NOUN'),
#  ('has', 'VERB'),
#  ('kept', 'VERB'),
#  ('the', 'DET'),
#  ('purchasing', 'NOUN'),
#  ('power', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('weekly', 'ADJ'),
#  ('paycheck', 'ADP'),
#  ('reasonably', 'ADP'),
#  ('strong', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('At', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('time', 'NOUN'),
#  (',', '.'),
#  ('though', 'ADP'),
#  (',', '.'),
#  ('he', 'PRON'),
#  ('chastised', 'VERB'),
#  ('the', 'DET'),
#  ('media', 'NOUN'),
#  ('for', 'ADP'),
#  ('*', 'X'),
#  ('paying', 'VERB'),
#  ('such', 'ADJ'),
#  ('close', 'NOUN'),
#  ('attention', 'NOUN'),
#  ('to', 'PRT'),
#  ('Japanese', 'ADJ'),
#  ('investment', 'NOUN'),
#  ('when', 'ADV'),
#  ('other', 'ADJ'),
#  ('foreign', 'ADJ'),
#  ('countries', 'NOUN'),
#  (',', '.'),
#  ('notably', 'ADV'),
#  ('Britain', 'NOUN'),
#  (',', '.'),
#  ('are', 'VERB'),
#  ('acquiring', 'VERB'),
#  ('more', 'ADV'),
#  ('American', 'ADJ'),
#  ('assets', 'NOUN'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('*-1', 'X'),
#  ('Funded', 'ADP'),
#  ('*-2', 'X'),
#  ('by', 'ADP'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('1', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('gift', 'NOUN'),
#  ('from', 'ADP'),
#  ('Tokio', 'ADP'),
#  ('Marine', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Fire', 'NOUN'),
#  ('Insurance', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('service', 'NOUN'),
#  ('will', 'VERB'),
#  ('follow', 'VERB'),
#  ('Japanese', 'ADJ'),
#  ('medical', 'ADJ'),
#  ('protocols', 'ADP'),
#  (',', '.'),
#  ('including', 'VERB'),
#  ('emphasis', 'NOUN'),
#  ('on', 'ADP'),
#  ('preventative', 'ADP'),
#  ('medicine', 'NOUN'),
#  ('.', '.'),
#  ('On', 'ADP'),
#  ('the', 'DET'),
#  ('other', 'ADJ'),
#  ('hand', 'NOUN'),
#  (',', '.'),
#  ('had', 'VERB'),
#  ('it', 'PRON'),
#  ('existed', 'ADP'),
#  ('then', 'ADV'),
#  (',', '.'),
#  ('Cray', 'NOUN'),
#  ('Computer', 'NOUN'),
#  ('would', 'VERB'),
#  ('have', 'VERB'),
#  ('incurred', 'VERB'),
#  ('a', 'DET'),
#  ('$', '.'),
#  ('20.5', 'ADP'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('loss', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('The', 'DET'),
#  ('disturbing', 'ADJ'),
#  ('thing', 'NOUN'),
#  ('about', 'ADP'),
#  ('this', 'DET'),
#  ('abortion', 'NOUN'),
#  ('issue', 'NOUN'),
#  ('is', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('debate', 'NOUN'),
#  ('has', 'VERB'),
#  ('become', 'VERB'),
#  ('polarized', 'ADP'),
#  ('*-1', 'X'),
#  (',', '.'),
#  ('so', 'ADV'),
#  ('that', 'ADP'),
#  ('no', 'DET'),
#  ('mechanism', 'NOUN'),
#  ('*ICH*-2', 'X'),
#  ('exists', 'ADP'),
#  ("''", '.'),
#  ('for', 'ADP'),
#  ('*', 'X'),
#  ('finding', 'VERB'),
#  ('a', 'DET'),
#  ('middle', 'NOUN'),
#  ('ground', 'NOUN'),
#  ('.', '.'),
#  ('Though', 'ADP'),
#  ('some', 'DET'),
#  ('lawyers', 'NOUN'),
#  ('reported', 'VERB'),
#  ('that', 'ADP'),
#  ('prospective', 'ADJ'),
#  ('acquirers', 'ADP'),
#  ('were', 'VERB'),
#  ('scrambling', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('filings', 'NOUN'),
#  ('before', 'ADP'),
#  ('the', 'DET'),
#  ('fees', 'NOUN'),
#  ('take', 'VERB'),
#  ('effect', 'NOUN'),
#  (',', '.'),
#  ('government', 'NOUN'),
#  ('officials', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('they', 'PRON'),
#  ('had', 'VERB'),
#  ("n't", 'ADV'),
#  ('noticed', 'ADP'),
#  ('any', 'DET'),
#  ('surge', 'NOUN'),
#  ('in', 'ADP'),
#  ('filings', 'NOUN'),
#  ('.', '.'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('volume', 'NOUN'),
#  ('totaled', 'VERB'),
#  ('154.2', 'ADP'),
#  ('million', 'NUM'),
#  ('shares', 'NOUN'),
#  ('.', '.'),
#  ('Since', 'ADP'),
#  ('chalk', 'ADP'),
#  ('first', 'ADJ'),
#  ('touched', 'ADP'),
#  ('slate', 'ADP'),
#  (',', '.'),
#  ('schoolchildren', 'ADP'),
#  ('have', 'VERB'),
#  ('wanted', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('know', 'VERB'),
#  (':', '.'),
#  ('What', 'PRON'),
#  ("'s", 'VERB'),
#  ('*T*-2', 'X'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('test', 'NOUN'),
#  ('?', '.'),
#  ('Moreover', 'ADV'),
#  (',', '.'),
#  ('they', 'PRON'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('appropriations', 'NOUN'),
#  ('bill', 'NOUN'),
#  ('passed', 'VERB'),
#  ('*', 'X'),
#  ('200', 'NUM'),
#  ('years', 'NOUN'),
#  ('ago', 'ADP'),
#  ('covered', 'VERB'),
#  ('many', 'ADJ'),
#  ('different', 'ADJ'),
#  ('items', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('there', 'DET'),
#  ('was', 'VERB'),
#  ('no', 'DET'),
#  ('discussion', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('line-item', 'ADJ'),
#  ('veto', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Wall', 'NOUN'),
#  ('Street', 'NOUN'),
#  ('is', 'VERB'),
#  ('facing', 'VERB'),
#  ('a', 'DET'),
#  ('Catch-22', 'ADP'),
#  ('situation', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Mr.', 'NOUN'),
#  ('Mahoney', 'NOUN'),
#  ('of', 'ADP'),
#  ('Moody', 'NOUN'),
#  ("'s", 'PRT'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('ban', 'NOUN'),
#  ('on', 'ADP'),
#  ('cross-border', 'ADP'),
#  ('movement', 'NOUN'),
#  ('was', 'VERB'),
#  ('imposed', 'VERB'),
#  ('*-1', 'X'),
#  ('last', 'ADJ'),
#  ('month', 'NOUN'),
#  ('after', 'ADP'),
#  ('a', 'DET'),
#  ('massive', 'ADJ'),
#  ('exodus', 'NOUN'),
#  ('of', 'ADP'),
#  ('emigres', 'ADP'),
#  ('to', 'PRT'),
#  ('West', 'NOUN'),
#  ('Germany', 'NOUN'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Ross', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('he', 'PRON'),
#  ('met', 'VERB'),
#  ('with', 'ADP'),
#  ('officials', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('IRS', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('Justice', 'NOUN'),
#  ('Department', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-133', 'ADP'),
#  ('would', 'VERB'),
#  ('bring', 'VERB'),
#  ('any', 'DET'),
#  ('enforcement', 'NOUN'),
#  ('actions', 'NOUN'),
#  ('against', 'ADP'),
#  ('taxpayers', 'NOUN'),
#  (',', '.'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('discuss', 'VERB'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('last', 'ADJ'),
#  ('May', 'NOUN'),
#  ('.', '.'),
#  ('Among', 'ADP'),
#  ('other', 'ADJ'),
#  ('things', 'NOUN'),
#  (',', '.'),
#  ('it', 'PRON'),
#  ('included', 'VERB'),
#  ('checking', 'NOUN'),
#  (',', '.'),
#  ('safe', 'ADP'),
#  ('deposit', 'NOUN'),
#  ('box', 'NOUN'),
#  ('and', 'CONJ'),
#  ('credit', 'NOUN'),
#  ('card', 'NOUN'),
#  ('--', '.'),
#  ('all', 'DET'),
#  ('for', 'ADP'),
#  ('free', 'ADJ'),
#  ('--', '.'),
#  ('plus', 'CONJ'),
#  ('a', 'DET'),
#  ('good', 'ADJ'),
#  ('deal', 'NOUN'),
#  ('on', 'ADP'),
#  ('installment', 'NOUN'),
#  ('loans', 'NOUN'),
#  ('.', '.'),
#  ('Fujitsu', 'NOUN'),
#  ('Ltd.', 'NOUN'),
#  ("'s", 'PRT'),
#  ('top', 'ADJ'),
#  ('executive', 'NOUN'),
#  ('took', 'VERB'),
#  ('the', 'DET'),
#  ('unusual', 'ADJ'),
#  ('step', 'NOUN'),
#  ('of', 'ADP'),
#  ('*', 'X'),
#  ('publicly', 'ADV'),
#  ('apologizing', 'ADP'),
#  ('for', 'ADP'),
#  ('his', 'PRON'),
#  ('company', 'NOUN'),
#  ("'s", 'PRT'),
#  ('making', 'VERB'),
#  ('bids', 'NOUN'),
#  ('of', 'ADP'),
#  ('just', 'ADV'),
#  ('one', 'NUM'),
#  ('yen', 'NOUN'),
#  ('for', 'ADP'),
#  ('several', 'ADJ'),
#  ('local', 'ADJ'),
#  ('government', 'NOUN'),
#  ('projects', 'NOUN'),
#  (',', '.'),
#  ('while', 'ADP'),
#  ('computer', 'NOUN'),
#  ('rival', 'NOUN'),
#  ('NEC', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('written', 'VERB'),
#  ('apology', 'NOUN'),
#  ('for', 'ADP'),
#  ('*', 'X'),
#  ('indulging', 'ADP'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('practice', 'NOUN'),
#  ('.', '.'),
#  ('From', 'ADP'),
#  ('1953', 'ADP'),
#  ('to', 'PRT'),
#  ('1955', 'ADP'),
#  (',', '.'),
#  ('9.8', 'NUM'),
#  ('billion', 'NUM'),
#  ('Kent', 'NOUN'),
#  ('cigarettes', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('filters', 'NOUN'),
#  ('were', 'VERB'),
#  ('sold', 'VERB'),
#  ('*-3', 'X'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Some', 'DET'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('homeless', 'ADJ'),
#  (',', '.'),
#  ('obviously', 'ADV'),
#  (',', '.'),
#  ('had', 'VERB'),
#  ('pre-existing', 'ADP'),
#  ('mental', 'ADJ'),
#  ('illness', 'NOUN'),
#  ('or', 'CONJ'),
#  ('addiction', 'ADP'),
#  ('.', '.'),
#  ('``', '.'),
#  ('We', 'PRON'),
#  ("'re", 'VERB'),
#  ('gaining', 'VERB'),
#  ('1,200', 'ADP'),
#  ('new', 'ADJ'),
#  ('customers', 'NOUN'),
#  ('each', 'DET'),
#  ('week', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Jack', 'NOUN'),
#  ('Mogavero', 'ADP'),
#  ('of', 'ADP'),
#  ('General', 'NOUN'),
#  ('Health', 'NOUN'),
#  ('Care', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  (',', '.'),
#  ('Piscataway', 'ADP'),
#  (',', '.'),
#  ('N.J', 'NOUN'),
#  ('.', '.'),
#  ('It', 'PRON'),
#  ('all', 'DET'),
#  ('adds', 'VERB'),
#  ('up', 'ADV'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('barrier', 'NOUN'),
#  ('to', 'PRT'),
#  ('American-style', 'ADP'),
#  ('index', 'NOUN'),
#  ('arbitrage', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('most', 'ADJ'),
#  ('popular', 'ADJ'),
#  ('form', 'NOUN'),
#  ('of', 'ADP'),
#  ('U.S.', 'NOUN'),
#  ('program', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('that', 'ADP'),
#  ('*T*-253', 'ADP'),
#  ('seeks', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('exploit', 'ADP'),
#  ('brief', 'ADJ'),
#  ('differences', 'NOUN'),
#  ('between', 'ADP'),
#  ('prices', 'NOUN'),
#  ('of', 'ADP'),
#  ('stocks', 'NOUN'),
#  ('in', 'ADP'),
#  ('New', 'NOUN'),
#  ('York', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('futures', 'NOUN'),
#  ('contract', 'NOUN'),
#  ('in', 'ADP'),
#  ('Chicago', 'NOUN'),
#  ('based', 'VERB'),
#  ('on', 'ADP'),
#  ('those', 'DET'),
#  ('stocks', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('great', 'ADJ'),
#  ('reds', 'ADP'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('Rhone', 'ADP'),
#  ('Valley', 'NOUN'),
#  ('have', 'VERB'),
#  ('soared', 'VERB'),
#  ('in', 'ADP'),
#  ('price', 'NOUN'),
#  ('as', 'ADP'),
#  ('well', 'ADV'),
#  ('.', '.'),
#  ('That', 'DET'),
#  ('followed', 'VERB'),
#  ('four', 'NUM'),
#  ('straight', 'ADJ'),
#  ('months', 'NOUN'),
#  ('in', 'ADP'),
#  ('which', 'DET'),
#  ('the', 'DET'),
#  ('number', 'NOUN'),
#  ('of', 'ADP'),
#  ('increases', 'NOUN'),
#  ('trailed', 'VERB'),
#  ('the', 'DET'),
#  ('year-earlier', 'ADJ'),
#  ('pace', 'NOUN'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Revenue', 'NOUN'),
#  ('rose', 'VERB'),
#  ('42', 'NUM'),
#  ('%', 'NOUN'),
#  ('to', 'PRT'),
#  ('$', '.'),
#  ('133.7', 'ADP'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('from', 'ADP'),
#  ('$', '.'),
#  ('94', 'ADP'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('.', '.'),
#  ('When', 'ADV'),
#  ('test', 'VERB'),
#  ('booklets', 'NOUN'),
#  ('were', 'VERB'),
#  ('passed', 'VERB'),
#  ('*-1', 'X'),
#  ('out', 'PRT'),
#  ('48', 'NUM'),
#  ('hours', 'NOUN'),
#  ('ahead', 'ADV'),
#  ('of', 'ADP'),
#  ('time', 'NOUN'),
#  ('*T*-2', 'X'),
#  (',', '.'),
#  ('she', 'PRON'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('she', 'PRON'),
#  ('copied', 'ADP'),
#  ('questions', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('social', 'ADJ'),
#  ('studies', 'NOUN'),
#  ('section', 'NOUN'),
#  ('and', 'CONJ'),
#  ('gave', 'VERB'),
#  ('the', 'DET'),
#  ('answers', 'NOUN'),
#  ('to', 'PRT'),
#  ('students', 'NOUN'),
#  ('.', '.'),
#  ('They', 'PRON'),
#  ('belong', 'VERB'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('group', 'NOUN'),
#  ('of', 'ADP'),
#  ('15', 'NUM'),
#  ('ringers', 'NOUN'),
#  ('--', '.'),
#  ('including', 'VERB'),
#  ('two', 'NUM'),
#  ('octogenarians', 'ADP'),
#  ('and', 'CONJ'),
#  ('four', 'NUM'),
#  ('youngsters', 'NOUN'),
#  ('in', 'ADP'),
#  ('training', 'NOUN'),
#  ('--', '.'),
#  ('who', 'PRON'),
#  ('*T*-222', 'ADP'),
#  ('drive', 'VERB'),
#  ('every', 'DET'),
#  ('Sunday', 'NOUN'),
#  ('from', 'ADP'),
#  ('church', 'NOUN'),
#  ('to', 'PRT'),
#  ('church', 'NOUN'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('sometimes-exhausting', 'ADP'),
#  ('effort', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('keep', 'VERB'),
#  ('the', 'DET'),
#  ('bells', 'NOUN'),
#  ('sounding', 'ADP'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('many', 'ADJ'),
#  ('belfries', 'ADP'),
#  ('of', 'ADP'),
#  ('East', 'NOUN'),
#  ('Anglia', 'ADP'),
#  ('.', '.'),
#  ('Imports', 'NOUN'),
#  ('of', 'ADP'),
#  ('manmade-fiber', 'ADP'),
#  ('sweaters', 'NOUN'),
#  ('in', 'ADP'),
#  ('1988', 'NUM'),
#  ('totaled', 'VERB'),
#  ('about', 'ADP'),
#  ('$', '.'),
#  ('405', 'ADP'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('from', 'ADP'),
#  ('Taiwan', 'NOUN'),
#  (',', '.'),
#  ('$', '.'),
#  ('400', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('from', 'ADP'),
#  ('South', 'NOUN'),
#  ('Korea', 'NOUN'),
#  ('and', 'CONJ'),
#  ('$', '.'),
#  ('125', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('from', 'ADP'),
#  ('Hong', 'NOUN'),
#  ('Kong', 'NOUN'),
#  (',', '.'),
#  ('according', 'VERB'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('ITC', 'NOUN'),
#  ('.', '.'),
#  ('What', 'PRON'),
#  ('*T*-102', 'ADP'),
#  ("'s", 'PRT'),
#  ('more', 'ADJ'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('test', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Learning', 'NOUN'),
#  ('Materials', 'NOUN'),
#  ('are', 'VERB'),
#  ('both', 'DET'),
#  ('produced', 'VERB'),
#  ('*-1', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('same', 'ADJ'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('Macmillan\\/McGraw-Hill', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('joint', 'ADJ'),
#  ('venture', 'NOUN'),
#  ('of', 'ADP'),
#  ('McGraw-Hill', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Macmillan', 'NOUN'),
#  ("'s", 'PRT'),
#  ('parent', 'NOUN'),
#  (',', '.'),
#  ('Britain', 'NOUN'),
#  ("'s", 'PRT'),
#  ('Maxwell', 'NOUN'),
#  ('Communication', 'ADP'),
#  ('Corp', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('year', 'NOUN'),
#  ('it', 'PRON'),
#  ('is', 'VERB'),
#  ('expected', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('a', 'DET'),
#  ('net', 'ADJ'),
#  ('importer', 'ADP'),
#  ('and', 'CONJ'),
#  ('is', 'VERB'),
#  ('said', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('seeking', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('buy', 'VERB'),
#  ('about', 'ADP'),
#  ('200,000', 'NUM'),
#  ('tons', 'NOUN'),
#  ('of', 'ADP'),
#  ('sugar', 'NOUN'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('meet', 'VERB'),
#  ('internal', 'ADJ'),
#  ('needs', 'NOUN'),
#  (',', '.'),
#  ('analysts', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-4', 'X'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('trial', 'NOUN'),
#  ('is', 'VERB'),
#  ('expected', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('last', 'ADJ'),
#  ('five', 'NUM'),
#  ('weeks', 'NOUN'),
#  ('.', '.'),
#  ('ShareData', 'NOUN'),
#  ('develops', 'ADP'),
#  ('and', 'CONJ'),
#  ('markets', 'NOUN'),
#  ('low-cost', 'ADP'),
#  ('software', 'NOUN'),
#  (',', '.'),
#  ('peripheral', 'ADJ'),
#  ('equipment', 'NOUN'),
#  ('and', 'CONJ'),
#  ('accessories', 'NOUN'),
#  ('for', 'ADP'),
#  ('computers', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('separate', 'ADJ'),
#  ('floor', 'NOUN'),
#  ('action', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('House', 'NOUN'),
#  ('waived', 'ADP'),
#  ('budget', 'NOUN'),
#  ('restrictions', 'NOUN'),
#  ('and', 'CONJ'),
#  ('gave', 'VERB'),
#  ('quick', 'ADJ'),
#  ('approval', 'NOUN'),
#  ('to', 'PRT'),
#  ('$', '.'),
#  ('3.18', 'NUM'),
#  ('billion', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('supplemental', 'ADP'),
#  ('appropriations', 'NOUN'),
#  ('for', 'ADP'),
#  ('law', 'NOUN'),
#  ('enforcement', 'NOUN'),
#  ('and', 'CONJ'),
#  ('anti-drug', 'ADP'),
#  ('programs', 'NOUN'),
#  ('in', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1990', 'NUM'),
#  ('.', '.'),
#  ('It', 'PRON'),
#  ('has', 'VERB'),
#  ('no', 'DET'),
#  ('bearing', 'VERB'),
#  ('on', 'ADP'),
#  ('our', 'PRON'),
#  ('work', 'VERB'),
#  ('force', 'VERB'),
#  ('today', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('he', 'PRON'),
#  ('has', 'VERB'),
#  ('not', 'ADV'),
#  ('said', 'VERB'),
#  ('before', 'ADP'),
#  ('that', 'DET'),
#  ('the', 'DET'),
#  ('country', 'NOUN'),
#  ('wants', 'VERB'),
#  ('half', 'DET'),
#  ('the', 'DET'),
#  ('debt', 'NOUN'),
#  ('forgiven', 'VERB'),
#  ('*-2', 'X'),
#  ('.', '.'),
#  ('Also', 'ADV'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Canepa', 'NOUN'),
#  ('received', 'VERB'),
#  ('a', 'DET'),
#  ('two-week', 'ADJ'),
#  ('suspension', 'NOUN'),
#  ('``', '.'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('principal', 'NOUN'),
#  ('capacity', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('``', '.'),
#  ('The', 'DET'),
#  ('IRS', 'NOUN'),
#  ('is', 'VERB'),
#  ('asking', 'VERB'),
#  ('lawyers', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('red-flag', 'ADP'),
#  ('a', 'DET'),
#  ('criminal', 'ADJ'),
#  ('problem', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('government', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('added', 'VERB'),
#  ('Mr.', 'NOUN'),
#  ('Sonnett', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('Miami', 'NOUN'),
#  ('lawyer', 'NOUN'),
#  ('who', 'PRON'),
#  ('*T*-128', 'ADP'),
#  ('has', 'VERB'),
#  ('heard', 'VERB'),
#  ('from', 'ADP'),
#  ('dozens', 'NOUN'),
#  ('of', 'ADP'),
#  ('attorneys', 'NOUN'),
#  ('who', 'PRON'),
#  ('*T*-129', 'ADP'),
#  ('received', 'VERB'),
#  ('letters', 'NOUN'),
#  ('in', 'ADP'),
#  ('recent', 'ADJ'),
#  ('days', 'NOUN'),
#  ('and', 'CONJ'),
#  ('has', 'VERB'),
#  ('himself', 'PRON'),
#  ('received', 'VERB'),
#  ('the', 'DET'),
#  ('computer-generated', 'ADP'),
#  ('IRS', 'NOUN'),
#  ('forms', 'NOUN'),
#  ('sent', 'VERB'),
#  ('*', 'X'),
#  ('by', 'ADP'),
#  ('certified', 'ADP'),
#  ('mail', 'ADP'),
#  ('.', '.'),
#  ('During', 'ADP'),
#  ('the', 'DET'),
#  ('coming', 'VERB'),
#  ('weeks', 'NOUN'),
#  (',', '.'),
#  ('President', 'NOUN'),
#  ('Bush', 'NOUN'),
#  ('must', 'VERB'),
#  ('decide', 'VERB'),
#  ('whether', 'ADP'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('veto', 'NOUN'),
#  ('the', 'DET'),
#  ('bills', 'NOUN'),
#  ('containing', 'ADP'),
#  ('them', 'PRON'),
#  ('--', '.'),
#  ('or', 'CONJ'),
#  (',', '.'),
#  ('alternatively', 'ADP'),
#  (',', '.'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('sign', 'NOUN'),
#  ('these', 'DET'),
#  ('bills', 'NOUN'),
#  ('into', 'ADP'),
#  ('law', 'NOUN'),
#  ('with', 'ADP'),
#  ('a', 'DET'),
#  ('statement', 'NOUN'),
#  ('declaring', 'VERB'),
#  ('their', 'PRON'),
#  ('intrusions', 'ADP'),
#  ('on', 'ADP'),
#  ('executive', 'NOUN'),
#  ('power', 'NOUN'),
#  ...]

# %% [markdown]
# ## Model 1: Consider only transition probability for unknown words
# #### Viterbi Algorithm with modification to Emission and Transition Probability
#
# - If the emission probability for a word is 0 i.e new word, let the transition probability alone decide the new tag.

# %%
#Viterbi Heuristic
def Viterbi_only_transition_prob(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        trans=[]
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p
            p.append(state_probability)
            trans.append(transition_p)
    
        pmax = max(p)
        # getting state for which probability is maximum
        if pmax == 0: #Emission probability is 0 and hence it is a new word.
            pmax = max(trans) # In such case find the maximum transition probability.
            state_max = T[trans.index(pmax)] # Let this transition prob decide the new tag.
        else:
            state_max = T[p.index(pmax)] # If emission prob !=0 then let the state_probability decide the tag as usual. 
        state.append(state_max)
    return list(zip(words, state))

# %%
start = time.time()
m1_tagged_seq = Viterbi_only_transition_prob(test_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ",difference)
# Out:
# Time taken in seconds:  1916.6774547100067

# %%
acc = measure_accuracy(m1_tagged_seq,test_run_base)
print("Accuracy with model1 Viterbi \t\t{:0.2f} %".format(acc*100))
# Out:
# Accuracy with model1 Viterbi 		93.89 %

# %%
find_incorrect_tags(m1_tagged_seq, test_run_base)
# Out:
# [[('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('Overseas', 'NOUN'), (('Private', 'ADJ'), ('Private', 'NOUN'))],
#  [('settled', 'VERB'), (('pre-1917', 'X'), ('pre-1917', 'ADJ'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('paycheck', 'NOUN'), (('reasonably', 'NOUN'), ('reasonably', 'ADV'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('from', 'ADP'), (('Tokio', 'DET'), ('Tokio', 'NOUN'))],
#  [('on', 'ADP'), (('preventative', 'DET'), ('preventative', 'ADJ'))],
#  [('$', '.'), (('20.5', 'NOUN'), ('20.5', 'NUM'))],
#  [('become', 'VERB'), (('polarized', 'X'), ('polarized', 'VERB'))],
#  [(',', '.'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('a', 'DET'), (('middle', 'NOUN'), ('middle', 'ADJ'))],
#  [('.', '.'), (('Though', 'NOUN'), ('Though', 'ADP'))],
#  [('totaled', 'VERB'), (('154.2', 'X'), ('154.2', 'NUM'))],
#  [('Since', 'ADP'), (('chalk', 'DET'), ('chalk', 'NOUN'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', 'NOUN'), ('touched', 'VERB'))],
#  [('on', 'ADP'), (('cross-border', 'DET'), ('cross-border', 'ADJ'))],
#  [('of', 'ADP'), (('emigres', 'DET'), ('emigres', 'NOUN'))],
#  [('which', 'DET'), (('*T*-133', 'NOUN'), ('*T*-133', 'X'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [(',', '.'), (('safe', 'NOUN'), ('safe', 'ADJ'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('From', 'ADP'), (('1953', 'DET'), ('1953', 'NUM'))],
#  [('to', 'PRT'), (('1955', 'VERB'), ('1955', 'NUM'))],
#  [('the', 'DET'), (('homeless', 'ADJ'), ('homeless', 'NOUN'))],
#  [('had', 'VERB'), (('pre-existing', 'X'), ('pre-existing', 'ADJ'))],
#  [('gaining', 'VERB'), (('1,200', 'X'), ('1,200', 'NUM'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('to', 'PRT'), (('American-style', 'VERB'), ('American-style', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-253', 'DET'), ('*T*-253', 'X'))],
#  [('price', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('$', '.'), (('133.7', 'NOUN'), ('133.7', 'NUM'))],
#  [('$', '.'), (('94', 'NOUN'), ('94', 'NUM'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('who', 'PRON'), (('*T*-222', 'VERB'), ('*T*-222', 'X'))],
#  [('a', 'DET'),
#   (('sometimes-exhausting', 'NOUN'), ('sometimes-exhausting', 'ADJ'))],
#  [('bells', 'NOUN'), (('sounding', 'NOUN'), ('sounding', 'VERB'))],
#  [('of', 'ADP'), (('manmade-fiber', 'DET'), ('manmade-fiber', 'ADJ'))],
#  [('$', '.'), (('405', 'NOUN'), ('405', 'NUM'))],
#  [('What', 'PRON'), (('*T*-102', 'VERB'), ('*T*-102', 'X'))],
#  [('*T*-102', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('to', 'PRT'), (('last', 'ADJ'), ('last', 'VERB'))],
#  [('ShareData', 'NOUN'), (('develops', 'NOUN'), ('develops', 'VERB'))],
#  [('and', 'CONJ'), (('markets', 'NOUN'), ('markets', 'VERB'))],
#  [('markets', 'VERB'), (('low-cost', 'NOUN'), ('low-cost', 'ADJ'))],
#  [('House', 'NOUN'), (('waived', 'NOUN'), ('waived', 'VERB'))],
#  [('in', 'ADP'), (('supplemental', 'DET'), ('supplemental', 'ADJ'))],
#  [('and', 'CONJ'), (('anti-drug', 'NOUN'), ('anti-drug', 'ADJ'))],
#  [('no', 'DET'), (('bearing', 'VERB'), ('bearing', 'NOUN'))],
#  [('our', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('before', 'ADP'), (('that', 'DET'), ('that', 'ADP'))],
#  [('a', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-128', 'VERB'), ('*T*-128', 'X'))],
#  [('who', 'PRON'), (('*T*-129', 'VERB'), ('*T*-129', 'X'))],
#  [('the', 'DET'),
#   (('computer-generated', 'NOUN'), ('computer-generated', 'ADJ'))],
#  [('by', 'ADP'), (('certified', 'DET'), ('certified', 'ADJ'))],
#  [('to', 'PRT'), (('veto', 'NOUN'), ('veto', 'VERB'))],
#  [('bills', 'NOUN'), (('containing', 'NOUN'), ('containing', 'VERB'))],
#  [(',', '.'), (('alternatively', 'NOUN'), ('alternatively', 'ADV'))],
#  [('to', 'PRT'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('their', 'PRON'), (('intrusions', 'VERB'), ('intrusions', 'NOUN'))],
#  [('on', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('thus', 'ADV'), (('void', 'VERB'), ('void', 'ADJ'))],
#  [(',', '.'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('$', '.'), (('43.875', 'NOUN'), ('43.875', 'NUM'))],
#  [("n't", 'ADV'), (('mind', 'NOUN'), ('mind', 'VERB'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('and', 'CONJ'), (('shopped', 'NOUN'), ('shopped', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('daily', 'ADJ'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [('of', 'ADP'), (('133.8', 'DET'), ('133.8', 'NUM'))],
#  [('$', '.'), (('2.47', 'NOUN'), ('2.47', 'NUM'))],
#  [('up', 'ADV'), (('7.4', 'VERB'), ('7.4', 'NUM'))],
#  [('$', '.'), (('2.30', 'NOUN'), ('2.30', 'NUM'))],
#  [('five-point', 'ADJ'), (('opening', 'NOUN'), ('opening', 'VERB'))],
#  [('$', '.'), (('13.625', 'NOUN'), ('13.625', 'NUM'))],
#  [('*-37', 'X'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('power', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Muzzling', 'NOUN'), ('Muzzling', 'ADJ'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('Anything', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('how', 'ADV'), (('about', 'ADP'), ('about', 'PRT'))],
#  [("''", '.'), (('quips', 'NOUN'), ('quips', 'VERB'))],
#  [('of', 'ADP'), (('Northampton', 'DET'), ('Northampton', 'NOUN'))],
#  [('including', 'VERB'), (('air', 'VERB'), ('air', 'NOUN'))],
#  [('air', 'NOUN'), (('bags', 'X'), ('bags', 'NOUN'))],
#  [('in', 'ADP'), (('front', 'NOUN'), ('front', 'ADJ'))],
#  [('improved', 'VERB'), (('side-crash', 'X'), ('side-crash', 'ADJ'))],
#  [('for', 'ADP'), (('alleged', 'ADJ'), ('alleged', 'VERB'))],
#  [('*', 'X'), (('Legend', 'VERB'), ('Legend', 'NOUN'))],
#  [('of', 'ADP'), (('multinational', 'DET'), ('multinational', 'ADJ'))],
#  [('a', 'DET'), (('wheel-loader', 'NOUN'), ('wheel-loader', 'ADJ'))],
#  [('in', 'ADP'), (('Heidelberg', 'DET'), ('Heidelberg', 'NOUN'))],
#  [(',', '.'), (('drink', 'NOUN'), ('drink', 'VERB'))],
#  [('and', 'CONJ'), (('desultory', 'NOUN'), ('desultory', 'ADJ'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('Yeargin', 'NOUN'), (('distinguished', 'NOUN'), ('distinguished', 'VERB'))],
#  [('distinguished', 'VERB'), (('herself', 'NOUN'), ('herself', 'PRON'))],
#  [('*-1', 'X'), (('forcing', 'VERB'), ('forcing', 'ADJ'))],
#  [('pair', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('using', 'VERB'), (('college-bowl', 'X'), ('college-bowl', 'NOUN'))],
#  [('diaper', 'NOUN'), (('covers', 'VERB'), ('covers', 'NOUN'))],
#  [('with', 'ADP'), (('Velcro', 'DET'), ('Velcro', 'NOUN'))],
#  [('fasteners', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('safety', 'NOUN'), (('pins', 'VERB'), ('pins', 'NOUN'))],
#  [('their', 'PRON'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('and', 'CONJ'), (('finance', 'NOUN'), ('finance', 'VERB'))],
#  [('selling', 'VERB'), (('non-core', 'X'), ('non-core', 'ADJ'))],
#  [('it', 'PRON'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('have', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('was', 'VERB'), (('appropriated', 'X'), ('appropriated', 'VERB'))],
#  [('--', '.'), (('twice', 'NOUN'), ('twice', 'ADV'))],
#  [('twice', 'ADV'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('creation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*-1', 'X'), (('noncompetitively', 'VERB'), ('noncompetitively', 'ADV'))],
#  [('*T*-1', 'X'), (('Wilfred', 'VERB'), ('Wilfred', 'NOUN'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('chief', 'ADJ'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('take', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('times', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('underlying', 'ADJ'), ('underlying', 'VERB'))],
#  [('adding', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [("'", 'PRT'), (('binders', 'VERB'), ('binders', 'NOUN'))],
#  [('$', '.'), (('93.9', 'NOUN'), ('93.9', 'NUM'))],
#  [('$', '.'), (('1.19', 'NOUN'), ('1.19', 'NUM'))],
#  [('$', '.'), (('92.9', 'NOUN'), ('92.9', 'NUM'))],
#  [('$', '.'), (('1.18', 'NOUN'), ('1.18', 'NUM'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('but', 'CONJ'), (('due', 'ADJ'), ('due', 'ADV'))],
#  [(',', '.'), (('overseas', 'ADV'), ('overseas', 'ADJ'))],
#  [('the', 'DET'), (('apparent', 'NOUN'), ('apparent', 'ADJ'))],
#  [('apparent', 'ADJ'), (('slowing', 'VERB'), ('slowing', 'NOUN'))],
#  [('on', 'ADP'), (('single-family', 'NOUN'), ('single-family', 'ADJ'))],
#  [("n't", 'ADV'), (('estimate', 'NOUN'), ('estimate', 'VERB'))],
#  [('a', 'DET'), (('razor-thin', 'NOUN'), ('razor-thin', 'ADJ'))],
#  [('IRS', 'NOUN'), (('rarely', 'NOUN'), ('rarely', 'ADV'))],
#  [('rarely', 'ADV'), (('acted', 'NOUN'), ('acted', 'VERB'))],
#  [('``', '.'), (('deplorable', 'NOUN'), ('deplorable', 'ADJ'))],
#  [('but', 'CONJ'), (('brushed', 'NOUN'), ('brushed', 'VERB'))],
#  [('off', 'PRT'), (('talk', 'VERB'), ('talk', 'NOUN'))],
#  [('0', 'X'), (('total', 'VERB'), ('total', 'ADJ'))],
#  [('were', 'VERB'), (('topped', 'X'), ('topped', 'VERB'))],
#  [('the', 'DET'), (('16.5', 'NOUN'), ('16.5', 'NUM'))],
#  [('contradict', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('-LRB-', '.'), (('technically', 'NOUN'), ('technically', 'ADV'))],
#  [('.', '.'), (('No', 'DET'), ('No', 'ADV'))],
#  [(',', '.'), (('triple', 'NOUN'), ('triple', 'ADV'))],
#  [('a', 'DET'), (('Washington-based', 'NOUN'), ('Washington-based', 'ADJ'))],
#  [('$', '.'), (('777', 'NOUN'), ('777', 'NUM'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('rose', 'VERB'), (('1.20', 'X'), ('1.20', 'NUM'))],
#  [('$', '.'), (('1.14', 'NOUN'), ('1.14', 'NUM'))],
#  [('of', 'ADP'), (('2163.2', 'DET'), ('2163.2', 'NUM'))],
#  [('last', 'ADJ'), (('half-hour', 'ADJ'), ('half-hour', 'NOUN'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('Lane', 'NOUN'), (('dreamed', 'NOUN'), ('dreamed', 'VERB'))],
#  [('highly', 'ADV'), (('improbable', 'VERB'), ('improbable', 'ADJ'))],
#  [("'s", 'PRT'), (('shop', 'VERB'), ('shop', 'NOUN'))],
#  [('expensive', 'ADJ'), (('high-rise', 'NOUN'), ('high-rise', 'ADJ'))],
#  [('Oct.', 'NOUN'), (('2-8', 'NOUN'), ('2-8', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('to', 'PRT'), (('A.C.', 'VERB'), ('A.C.', 'NOUN'))],
#  [('A.C.', 'NOUN'), (('Nielsen', 'X'), ('Nielsen', 'NOUN'))],
#  [('a', 'DET'), (('supportive', 'NOUN'), ('supportive', 'ADJ'))],
#  [('breakers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-215', 'DET'), ('*T*-215', 'X'))],
#  [('rose', 'VERB'), (('87.5', 'X'), ('87.5', 'NUM'))],
#  [('$', '.'), (('38.875', 'NOUN'), ('38.875', 'NUM'))],
#  [('frozen', 'VERB'), (('noodles', 'X'), ('noodles', 'NOUN'))],
#  [('and', 'CONJ'), (('pre-cooked', 'NOUN'), ('pre-cooked', 'ADJ'))],
#  [('in', 'ADP'), (('Clive', 'DET'), ('Clive', 'NOUN'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('of', 'ADP'), (('Smaby', 'DET'), ('Smaby', 'NOUN'))],
#  [('a', 'DET'), (('cosmetic', 'NOUN'), ('cosmetic', 'ADJ'))],
#  [('of', 'ADP'), (('Wertheim', 'DET'), ('Wertheim', 'NOUN'))],
#  [('and', 'CONJ'), (('entertaining', 'NOUN'), ('entertaining', 'ADJ'))],
#  [('that', 'DET'), (('means', 'NOUN'), ('means', 'VERB'))],
#  [('means', 'VERB'),
#   (('confrontational', 'NOUN'), ('confrontational', 'ADJ'))],
#  [('be', 'VERB'), (('refunded', 'X'), ('refunded', 'VERB'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NOUN'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'X'), ('suitors', 'NOUN'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('on', 'ADP'), (('66.5', 'DET'), ('66.5', 'NUM'))],
#  [('factors', 'NOUN'), (('affecting', 'NOUN'), ('affecting', 'VERB'))],
#  [('of', 'ADP'), (('seconds', 'DET'), ('seconds', 'NOUN'))],
#  [('a', 'DET'), (('low-tech', 'NOUN'), ('low-tech', 'ADJ'))],
#  [('can', 'VERB'), (('catch', 'NOUN'), ('catch', 'VERB'))],
#  [("'s", 'PRT'), (('fancy', 'VERB'), ('fancy', 'NOUN'))],
#  [('a', 'DET'), (('strategic', 'NOUN'), ('strategic', 'ADJ'))],
#  [('*', 'X'), (('servicing', 'NOUN'), ('servicing', 'VERB'))],
#  [('opportunities', 'NOUN'), (('arise', 'NOUN'), ('arise', 'VERB'))],
#  [('a', 'DET'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('or', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('more', 'ADV'), (('cumbersome', 'VERB'), ('cumbersome', 'ADJ'))],
#  [(':', '.'), (('day-care', 'NOUN'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('those', 'DET'), (('pressed', 'NOUN'), ('pressed', 'VERB'))],
#  [('are', 'VERB'), (('implemented', 'X'), ('implemented', 'VERB'))],
#  [(':', '.'), (('1', 'NUM'), ('1', 'X'))],
#  [(',', '.'), (('2', 'NUM'), ('2', 'X'))],
#  [('investment', 'NOUN'), (('focus', 'VERB'), ('focus', 'NOUN'))],
#  [('and', 'CONJ'), (('3', 'NUM'), ('3', 'X'))],
#  [('level', 'NOUN'), (('playing', 'VERB'), ('playing', 'NOUN'))],
#  [('their', 'PRON'), (('monopoly', 'VERB'), ('monopoly', 'NOUN'))],
#  [('yield', 'VERB'), (('7.422', 'X'), ('7.422', 'NUM'))],
#  [('So', 'ADV'), (('crunch', 'VERB'), ('crunch', 'NOUN'))],
#  [('from', 'ADP'), (('above', 'ADP'), ('above', 'ADV'))],
#  [('very', 'ADV'), (('obvious', 'VERB'), ('obvious', 'ADJ'))],
#  [('obvious', 'ADJ'), (('exit', 'X'), ('exit', 'NOUN'))],
#  [('at', 'ADP'), (('prayer', 'DET'), ('prayer', 'NOUN'))],
#  [('has', 'VERB'), (('minted', 'X'), ('minted', 'VERB'))],
#  [('of', 'ADP'), (('millionaires', 'DET'), ('millionaires', 'NOUN'))],
#  [('their', 'PRON'), (('20s', 'VERB'), ('20s', 'NUM'))],
#  [('and', 'CONJ'), (('30s', 'NOUN'), ('30s', 'NUM'))],
#  [('in', 'ADP'), (('replacement-car', 'DET'), ('replacement-car', 'NOUN'))],
#  [('in', 'ADP'), (('accidents', 'DET'), ('accidents', 'NOUN'))],
#  [('for', 'ADP'),
#   (('computer-system-design', 'DET'), ('computer-system-design', 'ADJ'))],
#  [('the', 'DET'), (('more-advanced', 'NOUN'), ('more-advanced', 'ADJ'))],
#  [('a', 'DET'), (('100-megabyte', 'NOUN'), ('100-megabyte', 'ADJ'))],
#  [('100-megabyte', 'ADJ'), (('hard', 'ADV'), ('hard', 'ADJ'))],
#  [('$', '.'), (('5,699', 'NOUN'), ('5,699', 'NUM'))],
#  [('$', '.'), (('6,799', 'NOUN'), ('6,799', 'NUM'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'ll", 'VERB'), (('weather', 'NOUN'), ('weather', 'VERB'))],
#  [('in', 'ADP'), (('Peninsula', 'DET'), ('Peninsula', 'NOUN'))],
#  [("'s", 'PRT'), (('floral', 'VERB'), ('floral', 'ADJ'))],
#  [('$', '.'), (('70-a-share', 'NOUN'), ('70-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('buy-back', 'NOUN'), ('buy-back', 'ADJ'))],
#  [('which', 'DET'), (('*T*-156', 'NOUN'), ('*T*-156', 'X'))],
#  [('earlier', 'ADJ'), (('tender', 'NOUN'), ('tender', 'ADJ'))],
#  [('continuing', 'VERB'), (('slow', 'VERB'), ('slow', 'ADJ'))],
#  [('``', '.'), (('mortgaged', 'NOUN'), ('mortgaged', 'VERB'))],
#  [('under', 'ADP'), (('price-support', 'DET'), ('price-support', 'ADJ'))],
#  [('open', 'ADJ'),
#   (('direct-investment', 'NOUN'), ('direct-investment', 'ADJ'))],
#  [('of', 'ADP'), (('Charlie', 'DET'), ('Charlie', 'NOUN'))],
#  [("'s", 'PRT'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('not', 'ADV'), (('volunteer', 'VERB'), ('volunteer', 'NOUN'))],
#  [('volunteer', 'NOUN'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('--', '.'), (('teetering', 'NOUN'), ('teetering', 'VERB'))],
#  [('on', 'ADP'), (('insolvency', 'DET'), ('insolvency', 'NOUN'))],
#  [('a', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('reported', 'VERB'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('better', 'ADJ'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('an', 'DET'), (('avid', 'NOUN'), ('avid', 'ADJ'))],
#  [('People', 'NOUN'), (('close', 'VERB'), ('close', 'ADJ'))],
#  [('to', 'PRT'), (('guarantee', 'NOUN'), ('guarantee', 'VERB'))],
#  [('estimated', 'VERB'),
#   (('seven-million-ton', 'X'), ('seven-million-ton', 'ADJ'))],
#  [('seven-million-ton', 'ADJ'), (('cut', 'VERB'), ('cut', 'NOUN'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('acid', 'ADJ'), ('acid', 'NOUN'))],
#  [('on', 'ADP'), (('50.1', 'DET'), ('50.1', 'NUM'))],
#  [('succeeding', 'VERB'), (('Delmont', 'X'), ('Delmont', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('of', 'ADP'), (('Sigmund', 'DET'), ('Sigmund', 'NOUN'))],
#  [('$', '.'), (('24.95', 'NOUN'), ('24.95', 'NUM'))],
#  [('*U*', 'X'), (('tool', 'VERB'), ('tool', 'NOUN'))],
#  [('for', 'ADP'), (('do-it-yourself', 'DET'), ('do-it-yourself', 'ADJ'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('$', '.'), (('1.82', 'NOUN'), ('1.82', 'NUM'))],
#  [('$', '.'), (('84.29', 'NOUN'), ('84.29', 'NUM'))],
#  [('the', 'DET'), (('impending', 'VERB'), ('impending', 'ADJ'))],
#  [('impending', 'ADJ'), (('attack', 'VERB'), ('attack', 'NOUN'))],
#  [("n't", 'ADV'), (('enough', 'ADV'), ('enough', 'ADJ'))],
#  [('ring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('rumored', 'VERB'), (('target', 'VERB'), ('target', 'NOUN'))],
#  [('been', 'VERB'), (('enormously', 'X'), ('enormously', 'ADV'))],
#  [('was', 'VERB'), (('raring', 'X'), ('raring', 'ADJ'))],
#  [('with', 'ADP'), (('lap-shoulder', 'DET'), ('lap-shoulder', 'ADJ'))],
#  [('for', 'ADP'), (('rear', 'DET'), ('rear', 'ADJ'))],
#  [('was', 'VERB'), (('soliciting', 'X'), ('soliciting', 'VERB'))],
#  [('sell', 'VERB'), (('TXO', 'X'), ('TXO', 'NOUN'))],
#  [('*-5', 'X'), (('mindful', 'VERB'), ('mindful', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('from', 'ADP'), (('malignant', 'DET'), ('malignant', 'ADJ'))],
#  [(',', '.'), (('16.9', 'NOUN'), ('16.9', 'NUM'))],
#  [('0', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('with', 'ADP'), (('17.4', 'DET'), ('17.4', 'NUM'))],
#  [('and', 'CONJ'), (('18.6', 'NOUN'), ('18.6', 'NUM'))],
#  [('the', 'DET'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('most', 'ADV'), (('favored', 'VERB'), ('favored', 'ADJ'))],
#  [('abortionist', 'NOUN'),
#   (('accidentally', 'NOUN'), ('accidentally', 'ADV'))],
#  [('buy', 'VERB'), (('jam', 'X'), ('jam', 'NOUN'))],
#  [('other', 'ADJ'), (('war-rationed', 'NOUN'), ('war-rationed', 'ADJ'))],
#  [('have', 'VERB'), (('competed', 'X'), ('competed', 'VERB'))],
#  [('and', 'CONJ'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('would', 'VERB'), (('disclose', 'X'), ('disclose', 'VERB'))],
#  [("'s", 'PRT'), (('cost', 'VERB'), ('cost', 'NOUN'))],
#  [('$', '.'), (('1.50', 'NOUN'), ('1.50', 'NUM'))],
#  [('alleged', 'ADJ'), (('improper', 'NOUN'), ('improper', 'ADJ'))],
#  [('improper', 'ADJ'), (('use', 'VERB'), ('use', 'NOUN'))],
#  [('to', 'PRT'), (('crack', 'NOUN'), ('crack', 'VERB'))],
#  [('crack', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('was', 'VERB'), (('down', 'ADV'), ('down', 'ADP'))],
#  [('$', '.'), (('5.70', 'NOUN'), ('5.70', 'NUM'))],
#  [('$', '.'), (('494.50', 'NOUN'), ('494.50', 'NUM'))]]

# %% [markdown]
# ### Compare the tagging accuracies of the model1  with vanilla Viterbi algorithm
# - Compared to the 91.47% accuracy of vanilla Viterbi algorithm, the Viterbi considering only transition probability for unknown words gives an accuracy of almost 93.89%.

# %% [markdown]
# ### Words tagged correctly by model1 which were incorrectly tagged by vanilla Viterbi
#
# Some of the cases where the modified algorithm worked better are :
#     - ('Unemployment', 'NUM') was rightly tagged as ('Unemployment', 'NOUN')
#     - ('Overseas', 'NUM') was rightly tagged as ('Overseas', 'NOUN')
#     - ('paycheck', 'NUM') was rightly tagged as ('paycheck', 'NOUN')
#     - ('Funded', 'NUM') was rightly tagged as ('Funded', 'VERB')
#     - ('protocols', 'NUM') was rightly tagged as ('protocols', 'NOUN')

# %% [markdown]
# ## Model 2: Tag unknown words using rule based algorithm

# %%
def rule_based(words, state):
    
    # specify patterns for tagging
    # example from the NLTK book
    patterns = [
        (r'.*ing$', 'VERB'),              # gerund
        (r'.*ed$', 'VERB'),               # past tense
        (r'.*es$', 'VERB'),               # 3rd singular present
        (r'.*ould$', 'MD'),              # modals
        (r'.*\'s$', 'NN$'),              # possessive nouns
        (r'.*s$', 'NNS'),                # plural nouns
        (r'.*\*.*', 'X'),                # plural nouns 
        (r'([0-9])+.*$', 'NUM'), # cardinal numbers
        (r'.*', 'NOUN')                    # nouns
    ]
    
    regexp_tagger = nltk.RegexpTagger(patterns)
    
    for i,j in enumerate(state):
        #Rule-based tagging done only for new 'unknown' words.
        if j == "unknown":
            state[i] = regexp_tagger.tag([words[i]])[0][1]
    return words,state

# %%
# Modified Viterbi Heuristic with Rule Based
def Viterbi_rule_based(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else: 
                #If previous tag is 'unknown' make transition_p = 1, so that emission_p alone decides the tag. 
                if (state[-1] == 'unknown'):
                    transition_p = 1
                else:             
                    transition_p = tags_df.loc[state[-1], tag]
                
           
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p
            p.append(state_probability)   
        pmax = max(p)

        if pmax == 0:
            #if pmax = 0, means the the word is a new word, in such case mark the word tag as "unknown".
            state_max = "unknown"
        else:
            state_max = T[p.index(pmax)]
        state.append(state_max)
    
    word, state = rule_based(words, state) #Rule-based function called for all 'unknown' new words.
    return list(zip(words, state))

# %%
# Tagging the test sentences

start = time.time()
m2_tagged_seq = Viterbi_rule_based(test_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
# Out:
# Time taken in seconds:  1959.3257241249084

# %%
acc = measure_accuracy(m2_tagged_seq,test_run_base)
print("Accuracy with model2 Viterbi \t\t{:0.2f} %".format(acc*100))
# Out:
# Accuracy with model2 Viterbi 		95.03 %

# %%
find_incorrect_tags(m2_tagged_seq, test_run_base)
# Out:
# [[('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('the', 'DET'), (('Overseas', 'NNS'), ('Overseas', 'NOUN'))],
#  [('Overseas', 'NOUN'), (('Private', 'ADJ'), ('Private', 'NOUN'))],
#  [('settled', 'VERB'), (('pre-1917', 'NOUN'), ('pre-1917', 'ADJ'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('paycheck', 'NOUN'), (('reasonably', 'NOUN'), ('reasonably', 'ADV'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('medical', 'ADJ'), (('protocols', 'NNS'), ('protocols', 'NOUN'))],
#  [('on', 'ADP'), (('preventative', 'NOUN'), ('preventative', 'ADJ'))],
#  [(',', '.'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('*ICH*-2', 'X'), (('exists', 'NNS'), ('exists', 'VERB'))],
#  [('a', 'DET'), (('middle', 'NOUN'), ('middle', 'ADJ'))],
#  [('.', '.'), (('Though', 'NOUN'), ('Though', 'ADP'))],
#  [('prospective', 'ADJ'), (('acquirers', 'NNS'), ('acquirers', 'NOUN'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('on', 'ADP'), (('cross-border', 'NOUN'), ('cross-border', 'ADJ'))],
#  [('of', 'ADP'), (('emigres', 'VERB'), ('emigres', 'NOUN'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [(',', '.'), (('safe', 'NOUN'), ('safe', 'ADJ'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('the', 'DET'), (('homeless', 'ADJ'), ('homeless', 'NOUN'))],
#  [('had', 'VERB'), (('pre-existing', 'VERB'), ('pre-existing', 'ADJ'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('to', 'PRT'), (('American-style', 'NOUN'), ('American-style', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('exploit', 'NOUN'), ('exploit', 'VERB'))],
#  [('great', 'ADJ'), (('reds', 'NNS'), ('reds', 'NOUN'))],
#  [('price', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('two', 'NUM'), (('octogenarians', 'NNS'), ('octogenarians', 'NOUN'))],
#  [('a', 'DET'),
#   (('sometimes-exhausting', 'VERB'), ('sometimes-exhausting', 'ADJ'))],
#  [('many', 'ADJ'), (('belfries', 'VERB'), ('belfries', 'NOUN'))],
#  [('of', 'ADP'), (('manmade-fiber', 'NOUN'), ('manmade-fiber', 'ADJ'))],
#  [('*T*-102', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('to', 'PRT'), (('last', 'ADJ'), ('last', 'VERB'))],
#  [('ShareData', 'NOUN'), (('develops', 'NNS'), ('develops', 'VERB'))],
#  [('and', 'CONJ'), (('markets', 'NOUN'), ('markets', 'VERB'))],
#  [('markets', 'VERB'), (('low-cost', 'NOUN'), ('low-cost', 'ADJ'))],
#  [('in', 'ADP'), (('supplemental', 'NOUN'), ('supplemental', 'ADJ'))],
#  [('and', 'CONJ'), (('anti-drug', 'NOUN'), ('anti-drug', 'ADJ'))],
#  [('no', 'DET'), (('bearing', 'VERB'), ('bearing', 'NOUN'))],
#  [('our', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('before', 'ADP'), (('that', 'DET'), ('that', 'ADP'))],
#  [('a', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('to', 'PRT'), (('red-flag', 'NOUN'), ('red-flag', 'VERB'))],
#  [('the', 'DET'),
#   (('computer-generated', 'VERB'), ('computer-generated', 'ADJ'))],
#  [('by', 'ADP'), (('certified', 'VERB'), ('certified', 'ADJ'))],
#  [('to', 'PRT'), (('veto', 'NOUN'), ('veto', 'VERB'))],
#  [(',', '.'), (('alternatively', 'NOUN'), ('alternatively', 'ADV'))],
#  [('to', 'PRT'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('their', 'PRON'), (('intrusions', 'NNS'), ('intrusions', 'NOUN'))],
#  [('on', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('thus', 'ADV'), (('void', 'NOUN'), ('void', 'ADJ'))],
#  [(',', '.'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [("n't", 'ADV'), (('mind', 'NOUN'), ('mind', 'VERB'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('also', 'ADV'), (('helps', 'NNS'), ('helps', 'VERB'))],
#  [('farm', 'NOUN'), (('lobbies', 'VERB'), ('lobbies', 'NOUN'))],
#  [('daily', 'ADJ'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [('five-point', 'ADJ'), (('opening', 'NOUN'), ('opening', 'VERB'))],
#  [('*-37', 'X'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('power', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('wield', 'NOUN'), ('wield', 'VERB'))],
#  [('.', '.'), (('Muzzling', 'VERB'), ('Muzzling', 'ADJ'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('``', '.'), (('Anything', 'VERB'), ('Anything', 'NOUN'))],
#  [('Anything', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('how', 'ADV'), (('about', 'ADP'), ('about', 'PRT'))],
#  [("''", '.'), (('quips', 'NNS'), ('quips', 'VERB'))],
#  [('.', '.'), (('Fundamentalists', 'NNS'), ('Fundamentalists', 'NOUN'))],
#  [('including', 'VERB'), (('air', 'VERB'), ('air', 'NOUN'))],
#  [('air', 'NOUN'), (('bags', 'NNS'), ('bags', 'NOUN'))],
#  [('in', 'ADP'), (('front', 'NOUN'), ('front', 'ADJ'))],
#  [('improved', 'VERB'), (('side-crash', 'NOUN'), ('side-crash', 'ADJ'))],
#  [('for', 'ADP'), (('alleged', 'ADJ'), ('alleged', 'VERB'))],
#  [('a', 'DET'), (('word-processing', 'VERB'), ('word-processing', 'NOUN'))],
#  [('of', 'ADP'), (('multinational', 'NOUN'), ('multinational', 'ADJ'))],
#  [('a', 'DET'), (('wheel-loader', 'NOUN'), ('wheel-loader', 'ADJ'))],
#  [('wheel-loader', 'ADJ'),
#   (('manufacturing', 'VERB'), ('manufacturing', 'NOUN'))],
#  [(',', '.'), (('drink', 'NOUN'), ('drink', 'VERB'))],
#  [('and', 'CONJ'), (('desultory', 'NOUN'), ('desultory', 'ADJ'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('distinguished', 'VERB'), (('herself', 'NOUN'), ('herself', 'PRON'))],
#  [('teaching', 'NOUN'), (('approaches', 'VERB'), ('approaches', 'NOUN'))],
#  [('*-1', 'X'), (('forcing', 'VERB'), ('forcing', 'ADJ'))],
#  [('to', 'PRT'), (('pair', 'NOUN'), ('pair', 'VERB'))],
#  [('type', 'NOUN'), (('competitions', 'NNS'), ('competitions', 'NOUN'))],
#  [('diaper', 'NOUN'), (('covers', 'VERB'), ('covers', 'NOUN'))],
#  [('fasteners', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('safety', 'NOUN'), (('pins', 'VERB'), ('pins', 'NOUN'))],
#  [('their', 'PRON'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('and', 'CONJ'), (('finance', 'NOUN'), ('finance', 'VERB'))],
#  [('selling', 'VERB'), (('non-core', 'NOUN'), ('non-core', 'ADJ'))],
#  [('it', 'PRON'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('have', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('--', '.'), (('twice', 'NOUN'), ('twice', 'ADV'))],
#  [('twice', 'ADV'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('creation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*-1', 'X'), (('noncompetitively', 'NOUN'), ('noncompetitively', 'ADV'))],
#  [('*T*-1', 'X'), (('Wilfred', 'VERB'), ('Wilfred', 'NOUN'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('chief', 'ADJ'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('take', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('``', '.'), (('derivatives', 'VERB'), ('derivatives', 'NOUN'))],
#  [('times', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('underlying', 'ADJ'), ('underlying', 'VERB'))],
#  [('adding', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [("'", 'PRT'), (('binders', 'NNS'), ('binders', 'NOUN'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('but', 'CONJ'), (('due', 'ADJ'), ('due', 'ADV'))],
#  [(',', '.'), (('overseas', 'ADV'), ('overseas', 'ADJ'))],
#  [('the', 'DET'), (('apparent', 'NOUN'), ('apparent', 'ADJ'))],
#  [('apparent', 'ADJ'), (('slowing', 'VERB'), ('slowing', 'NOUN'))],
#  [('on', 'ADP'), (('single-family', 'NOUN'), ('single-family', 'ADJ'))],
#  [("n't", 'ADV'), (('estimate', 'NOUN'), ('estimate', 'VERB'))],
#  [('a', 'DET'), (('razor-thin', 'NOUN'), ('razor-thin', 'ADJ'))],
#  [('a', 'DET'), (('fledgling', 'VERB'), ('fledgling', 'NOUN'))],
#  [('to', 'PRT'), (('depend', 'NOUN'), ('depend', 'VERB'))],
#  [('IRS', 'NOUN'), (('rarely', 'NOUN'), ('rarely', 'ADV'))],
#  [('``', '.'), (('deplorable', 'NOUN'), ('deplorable', 'ADJ'))],
#  [('off', 'PRT'), (('talk', 'VERB'), ('talk', 'NOUN'))],
#  [('the', 'DET'), (('insurgents', 'NNS'), ('insurgents', 'NOUN'))],
#  [('0', 'X'), (('total', 'VERB'), ('total', 'ADJ'))],
#  [('contradict', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('-LRB-', '.'), (('technically', 'NOUN'), ('technically', 'ADV'))],
#  [('.', '.'), (('No', 'DET'), ('No', 'ADV'))],
#  [(',', '.'), (('triple', 'NOUN'), ('triple', 'ADV'))],
#  [('a', 'DET'), (('Washington-based', 'VERB'), ('Washington-based', 'ADJ'))],
#  [('to', 'PRT'), (('sue', 'NOUN'), ('sue', 'VERB'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('last', 'ADJ'), (('half-hour', 'ADJ'), ('half-hour', 'NOUN'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('highly', 'ADV'), (('improbable', 'NOUN'), ('improbable', 'ADJ'))],
#  [('expensive', 'ADJ'), (('high-rise', 'NOUN'), ('high-rise', 'ADJ'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('a', 'DET'), (('supportive', 'NOUN'), ('supportive', 'ADJ'))],
#  [('circuit', 'NOUN'), (('breakers', 'NNS'), ('breakers', 'NOUN'))],
#  [('breakers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('frozen', 'VERB'), (('noodles', 'VERB'), ('noodles', 'NOUN'))],
#  [('and', 'CONJ'), (('pre-cooked', 'VERB'), ('pre-cooked', 'ADJ'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('questionable', 'ADJ'), (('properties', 'VERB'), ('properties', 'NOUN'))],
#  [('a', 'DET'), (('cosmetic', 'NOUN'), ('cosmetic', 'ADJ'))],
#  [('S.', 'NOUN'), (('Gelles', 'VERB'), ('Gelles', 'NOUN'))],
#  [('and', 'CONJ'), (('entertaining', 'VERB'), ('entertaining', 'ADJ'))],
#  [('that', 'DET'), (('means', 'NOUN'), ('means', 'VERB'))],
#  [('means', 'VERB'),
#   (('confrontational', 'NOUN'), ('confrontational', 'ADJ'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NNS'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'NNS'), ('suitors', 'NOUN'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('of', 'ADP'), (('seconds', 'NNS'), ('seconds', 'NOUN'))],
#  [('a', 'DET'), (('low-tech', 'NOUN'), ('low-tech', 'ADJ'))],
#  [('can', 'VERB'), (('catch', 'NOUN'), ('catch', 'VERB'))],
#  [('a', 'DET'), (('strategic', 'NOUN'), ('strategic', 'ADJ'))],
#  [('strategic', 'ADJ'), (('fit', 'ADJ'), ('fit', 'NOUN'))],
#  [('*', 'X'), (('servicing', 'NOUN'), ('servicing', 'VERB'))],
#  [('opportunities', 'NOUN'), (('arise', 'NOUN'), ('arise', 'VERB'))],
#  [('a', 'DET'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('or', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('more', 'ADV'), (('cumbersome', 'NOUN'), ('cumbersome', 'ADJ'))],
#  [(':', '.'), (('day-care', 'NOUN'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(':', '.'), (('1', 'NUM'), ('1', 'X'))],
#  [(',', '.'), (('2', 'NUM'), ('2', 'X'))],
#  [('investment', 'NOUN'), (('focus', 'VERB'), ('focus', 'NOUN'))],
#  [('and', 'CONJ'), (('3', 'NUM'), ('3', 'X'))],
#  [('level', 'NOUN'), (('playing', 'VERB'), ('playing', 'NOUN'))],
#  [('from', 'ADP'), (('above', 'ADP'), ('above', 'ADV'))],
#  [('very', 'ADV'), (('obvious', 'NNS'), ('obvious', 'ADJ'))],
#  [('of', 'ADP'), (('millionaires', 'VERB'), ('millionaires', 'NOUN'))],
#  [('their', 'PRON'), (('20s', 'NNS'), ('20s', 'NUM'))],
#  [('and', 'CONJ'), (('30s', 'NNS'), ('30s', 'NUM'))],
#  [('replacement-car', 'NOUN'), (('rentals', 'NNS'), ('rentals', 'NOUN'))],
#  [('in', 'ADP'), (('accidents', 'NNS'), ('accidents', 'NOUN'))],
#  [('for', 'ADP'),
#   (('computer-system-design', 'NOUN'), ('computer-system-design', 'ADJ'))],
#  [('the', 'DET'), (('more-advanced', 'VERB'), ('more-advanced', 'ADJ'))],
#  [('four', 'NUM'), (('megabytes', 'VERB'), ('megabytes', 'NOUN'))],
#  [('a', 'DET'), (('100-megabyte', 'NUM'), ('100-megabyte', 'ADJ'))],
#  [('100-megabyte', 'ADJ'), (('hard', 'ADV'), ('hard', 'ADJ'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'ll", 'VERB'), (('weather', 'NOUN'), ('weather', 'VERB'))],
#  [("''", '.'), (('Citizens', 'NNS'), ('Citizens', 'NOUN'))],
#  [("'s", 'PRT'), (('floral', 'NOUN'), ('floral', 'ADJ'))],
#  [('$', '.'), (('70-a-share', 'NUM'), ('70-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('buy-back', 'NOUN'), ('buy-back', 'ADJ'))],
#  [('earlier', 'ADJ'), (('tender', 'NOUN'), ('tender', 'ADJ'))],
#  [('disturbing', 'ADJ'), (('developments', 'NNS'), ('developments', 'NOUN'))],
#  [('continuing', 'VERB'), (('slow', 'VERB'), ('slow', 'ADJ'))],
#  [('to', 'PRT'), (('reclaim', 'NOUN'), ('reclaim', 'VERB'))],
#  [('under', 'ADP'), (('price-support', 'NOUN'), ('price-support', 'ADJ'))],
#  [('open', 'ADJ'),
#   (('direct-investment', 'NOUN'), ('direct-investment', 'ADJ'))],
#  [("'s", 'PRT'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('volunteer', 'NOUN'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('a', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('reported', 'VERB'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('better', 'ADJ'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('an', 'DET'), (('avid', 'NOUN'), ('avid', 'ADJ'))],
#  [('People', 'NOUN'), (('close', 'VERB'), ('close', 'ADJ'))],
#  [('to', 'PRT'), (('guarantee', 'NOUN'), ('guarantee', 'VERB'))],
#  [('estimated', 'VERB'),
#   (('seven-million-ton', 'NOUN'), ('seven-million-ton', 'ADJ'))],
#  [('seven-million-ton', 'ADJ'), (('cut', 'VERB'), ('cut', 'NOUN'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('acid', 'ADJ'), ('acid', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('the', 'DET'), (('likeness', 'NNS'), ('likeness', 'NOUN'))],
#  [('for', 'ADP'), (('do-it-yourself', 'NOUN'), ('do-it-yourself', 'ADJ'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('the', 'DET'), (('impending', 'VERB'), ('impending', 'ADJ'))],
#  [('impending', 'ADJ'), (('attack', 'VERB'), ('attack', 'NOUN'))],
#  [("n't", 'ADV'), (('enough', 'ADV'), ('enough', 'ADJ'))],
#  [('ring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('rumored', 'VERB'), (('target', 'VERB'), ('target', 'NOUN'))],
#  [('been', 'VERB'), (('enormously', 'NOUN'), ('enormously', 'ADV'))],
#  [('was', 'VERB'), (('raring', 'VERB'), ('raring', 'ADJ'))],
#  [('to', 'PRT'), (('invent', 'NOUN'), ('invent', 'VERB'))],
#  [('--', '.'), (('IRAs', 'NNS'), ('IRAs', 'NOUN'))],
#  [('to', 'PRT'), (('equip', 'NOUN'), ('equip', 'VERB'))],
#  [('with', 'ADP'), (('lap-shoulder', 'NOUN'), ('lap-shoulder', 'ADJ'))],
#  [('for', 'ADP'), (('rear', 'NOUN'), ('rear', 'ADJ'))],
#  [('*-5', 'X'), (('mindful', 'NOUN'), ('mindful', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('from', 'ADP'), (('malignant', 'NOUN'), ('malignant', 'ADJ'))],
#  [('and', 'CONJ'), (('asbestosis', 'NNS'), ('asbestosis', 'NOUN'))],
#  [('0', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('the', 'DET'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('most', 'ADV'), (('favored', 'VERB'), ('favored', 'ADJ'))],
#  [('abortionist', 'NOUN'),
#   (('accidentally', 'NOUN'), ('accidentally', 'ADV'))],
#  [('other', 'ADJ'), (('war-rationed', 'VERB'), ('war-rationed', 'ADJ'))],
#  [('war-rationed', 'ADJ'), (('goodies', 'VERB'), ('goodies', 'NOUN'))],
#  [('the', 'DET'), (('reins', 'NNS'), ('reins', 'NOUN'))],
#  [('and', 'CONJ'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('would', 'VERB'), (('disclose', 'NOUN'), ('disclose', 'VERB'))],
#  [("'s", 'PRT'), (('cost', 'VERB'), ('cost', 'NOUN'))],
#  [('alleged', 'ADJ'), (('improper', 'NOUN'), ('improper', 'ADJ'))],
#  [('improper', 'ADJ'), (('use', 'VERB'), ('use', 'NOUN'))],
#  [('to', 'PRT'), (('crack', 'NOUN'), ('crack', 'VERB'))],
#  [('crack', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('was', 'VERB'), (('down', 'ADV'), ('down', 'ADP'))]]

# %% [markdown]
# ### Compare the tagging accuracies of the model2  with vanilla Viterbi algorithm
# - Compared to the 91.47% accuracy of vanilla Viterbi algorithm, the rule based Viterbi gives an accuracy of almost 95.03%.

# %% [markdown]
# ### Words tagged correctly by model2 which were incorrectly tagged by vanilla Viterbi
#
# Some of the cases where the modified algorithm worked better are :
#     - ('*T*-253', 'NUM') was now rightly tagged as ('*T*-253', 'X'))
#     - ('*T*-222', 'NUM') was now rightly tagged as ('*T*-222', 'X'))
#     - ('existed', 'NUM') was now rightly tagged as ('existed', 'VERB'))
#     - ('noticed', 'NUM') was now rightly tagged as ('noticed', 'VERB'))
#     - ('schoolchildren', 'NUM') was now rightly tagged as ('schoolchildren', 'NOUN')

# %% [markdown]
# ## Model 3: Tag unknown words using most commonly used tag

# %%
# find the most commonly used tag in training dataset
#Extract words and tags from training data set
words = [pair[0].lower() for pair in train_tagged_words]
tags = [pair[1] for pair in train_tagged_words]
tags_counter = Counter(tags)

#Finding the most common tag
print("Most common tags in the given training data set : \n {0}".format(tags_counter.most_common(5)))
# Out:
# Most common tags in the given training data set :
#  [('NOUN', 27423), ('VERB', 12885), ('.', 11118), ('ADP', 9345), ('DET', 8284)]

# %% [markdown]
# <b> We notice that "NOUN" is the most common tag in the training data set.

# %%
def most_common_tag(words, state):
    
    # specify patterns for tagging
    # example from the NLTK book
    patterns = [
        (r'.*ing$', 'VERB'),              # gerund
        (r'.*ed$', 'VERB'),               # past tense
        (r'.*es$', 'VERB'),               # 3rd singular present
        (r'.*ould$', 'MD'),              # modals
        (r'.*\'s$', 'NN$'),              # possessive nouns
        (r'.*s$', 'NNS'),                # plural nouns
        (r'.*\*.*', 'X'),                # plural nouns 
        (r'([0-9])+.*$', 'NUM'), # cardinal numbers
        (r'.*', 'NOUN')                    # nouns
    ]
    
    regexp_tagger = nltk.RegexpTagger(patterns)
    
    for i,j in enumerate(state):
        #Rule-based tagging done only for new 'unknown' words.
        if j == "unknown":
            state[i] = 'NOUN'
    return words,state

# %%
# Modified Viterbi Heuristic with Rule Based
def Viterbi_most_common_tag(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else: 
                #If previous tag is 'unknown' make transition_p = 1, so that emission_p alone decides the tag. 
                if (state[-1] == 'unknown'):
                    transition_p = 1
                else:             
                    transition_p = tags_df.loc[state[-1], tag]
                
           
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p
            p.append(state_probability)   
        pmax = max(p)

        if pmax == 0:
            #if pmax = 0, means the the word is a new word, in such case mark the word tag as "unknown".
            state_max = "unknown"
        else:
            state_max = T[p.index(pmax)]
        state.append(state_max)
    
    word, state = most_common_tag(words, state) #Rule-based function called for all 'unknown' new words.
    return list(zip(words, state))

# %%
# Tagging the test sentences

start = time.time()
m3_tagged_seq = Viterbi_most_common_tag(test_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
# Out:
# Time taken in seconds:  1921.6285433769226

# %%
acc = measure_accuracy(m3_tagged_seq,test_run_base)
print("Accuracy with model3 Viterbi \t\t{:0.2f} %".format(acc*100))
# Out:
# Accuracy with model3 Viterbi 		93.95 %

# %% [markdown]
# ### Compare the tagging accuracies of the model3  with vanilla Viterbi algorithm
# - Compared to the 91.47% accuracy of vanilla Viterbi algorithm, the rule based Viterbi gives an accuracy of almost 94%

# %% [markdown]
# # Evaluating models on sentences in sample test file

# %% [markdown]
# ### Run vanilla Viterbi on the sentences in sample file

# %%
nltk.download('punkt')
with open('sample_text.txt', 'r') as myfile:
    test_sentence = myfile.read()
    sentence_words = word_tokenize(test_sentence)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bindus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nltk.download('averaged_perceptron_tagger')
sampleFile_tags = nltk.pos_tag(sentence_words, tagset='universal')
sampleFile_tags
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\bindus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'NOUN'),
#  ('.', '.'),
#  ('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'NOUN'),
#  ('since', 'ADP'),
#  ('2011', 'NUM'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'NUM'),
#  ('.', '.'),
#  ('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NUM'),
#  ('that', 'DET'),
#  ('gave', 'VERB'),
#  ('Google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('firehose', 'NOUN'),
#  ('.', '.'),
#  ('Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'ADJ'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'NOUN'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'NOUN'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'ADJ'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'NUM'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NUM'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'VERB'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'NUM'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'VERB'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'VERB'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'VERB'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADV'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'NOUN'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'NOUN'),
#  ('invited', 'VERB'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'VERB'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %%
# list of words
sampleFile_words = [tup[0] for tup in sampleFile_tags]
#sampleFile_words

# %%
start = time.time()
sampleFile_tags_plain = Viterbi(sampleFile_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
# Out:
# Time taken in seconds:  67.31965398788452

# %%
acc = measure_accuracy(sampleFile_tags_plain, sampleFile_tags)

print("Accuracy with plain Viterbi \t\t{:0.2f} %".format(acc*100))
# Out:
# Accuracy with plain Viterbi 		76.24 %

# %% [markdown]
# ### Run modified Viterbi to consider only transitional probabilities on the sentences in sample file

# %%
start = time.time()
sampleFile_tags_m2 = Viterbi_only_transition_prob(sampleFile_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
sampleFile_tags_m2
# Out:
# Time taken in seconds:  78.9206337928772
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'DET'),
#  ('.', '.'),
#  ('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'DET'),
#  ('since', 'ADP'),
#  ('2011', 'DET'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'DET'),
#  ('.', '.'),
#  ('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'DET'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'X'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'VERB'),
#  ("'s", 'PRT'),
#  ('firehose', 'VERB'),
#  ('.', '.'),
#  ('Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'DET'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'DET'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'NOUN'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'DET'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %%
acc = measure_accuracy(sampleFile_tags_m2, sampleFile_tags)
print("Accuracy with modified Viterbi with transitional probabilities \t\t{:0.2f} %".format(acc*100))
# Out:
# Accuracy with modified Viterbi with transitional probabilities 		86.74 %

# %% [markdown]
# ### Words tagged correctly by model1 which were incorrectly tagged by vanilla Viterbi
# Some of the cases where the modified algorithm worked better are :
#
# - ('experience', 'VERB') is now rightly tagged as ('experience', 'NOUN')
# - ('Show', 'VERB') is now rightly tagged as ('Show', 'NOUN')
# - ('contested', 'NOUN') is now rightly tagged as ('contested', 'VERB')
# - ('that', 'DET') is now rightly tagged as ('that', 'ADP')

# %% [markdown]
# ### Run modified rule based Viterbi on the sentences in sample file

# %%
start = time.time()
sampleFile_tags_m3 = Viterbi_rule_based(sampleFile_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
sampleFile_tags_m3
# Out:
# Time taken in seconds:  67.73312711715698
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'NOUN'),
#  ('.', '.'),
#  ('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'VERB'),
#  ('since', 'ADP'),
#  ('2011', 'NUM'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'NUM'),
#  ('.', '.'),
#  ('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NUM'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('firehose', 'NOUN'),
#  ('.', '.'),
#  ('Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'VERB'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'NNS'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'VERB'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'NUM'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NUM'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'VERB'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NNS'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'VERB'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'NOUN'),
#  ('invited', 'VERB'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %%
acc = measure_accuracy(sampleFile_tags_m3, sampleFile_tags)
print("Accuracy with modified Viterbi which is rule based \t\t{:0.2f} %".format(acc*100))
# Out:
# Accuracy with modified Viterbi which is rule based 		92.27 %

# %% [markdown]
# ### Words tagged correctly by model2 which were incorrectly tagged by vanilla Viterbi
# Some of the cases where the modified algorithm worked better are :
#
# - ('online', 'ADJ') is now rightly tagged as ('online', 'NOUN')
# - ('arriving', 'NOUN') is now rightly tagged as ('arriving', 'VERB')
# - ('like', 'VERB') is now rightly tagged as ('like', 'ADP')
# - ('trips', 'NOUN') is now rightly tagged as ('trips', 'NNS')

# %% [markdown]
# ### Run modified Viterbi that tags unknown words with most common tag on the sentences in sample file

# %%
start = time.time()
sampleFile_tags_m4 = Viterbi_most_common_tag(sampleFile_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
sampleFile_tags_m4
# Out:
# Time taken in seconds:  68.8569540977478
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'NOUN'),
#  ('.', '.'),
#  ('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'NOUN'),
#  ('since', 'ADP'),
#  ('2011', 'NOUN'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'NOUN'),
#  ('.', '.'),
#  ('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NOUN'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('firehose', 'NOUN'),
#  ('.', '.'),
#  ('Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'NOUN'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'NOUN'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'NOUN'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %%
acc = measure_accuracy(sampleFile_tags_m4, sampleFile_tags)
print("Accuracy with modified Viterbi where the most common tag is picked is \t\t{:0.2f} %".format(acc*100))
# Out:
# Accuracy with modified Viterbi where the most common tag is picked is 		91.16 %

# %% [markdown]
# ### Words tagged correctly by model3  which were incorrectly tagged by vanilla Viterbi
# Some of the cases where the modified algorithm worked better are:
#
# - ('Show', 'VERB') is now correctly tagged as ('Show', 'NOUN')
# - ('11th', 'NUM') is now rightly tagged as ('11th', 'ADJ')
# - ('like', 'VERB') is now rightly tagged as ('like', 'ADP')
# - ('about', 'ADV') is now rightly tagged as ('about', 'ADP')

# %% [markdown]
# # Conclusions
#
# 1. The rule based Viterbi models perform much better than vanilla Viterbi and the Viterbi model that considers only transitional   probabilities for unknown words.
#
# 2. There are still some incorrect tags presennt after each of the methods, which may not be gramatically correct in a given context. This may be mainly because of the limited number of tags (12) in the dataset.
